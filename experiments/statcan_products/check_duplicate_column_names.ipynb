# %% [markdown]
# DuckDB treats all column names in a case insensitive manner. So "Value" and "VALUE" are treated the same, thus "VALUE" becomes "VALUE_1"
#
# An example of this happening is productId 38100105

# %%
from collections import Counter
import glob
import pprint

import duckdb
import pyarrow.parquet as pq

# %%
con = duckdb.connect()

issue = con.execute("SELECT * FROM '/data/tables/output/en/june_20_2025/38100105.parquet'").df()

issue.tail()
# Out:
#     REF_DATE REF_START_DATE REF_END_DATE     GEO DGUID  \
# 753     2010     2010-01-01   2010-12-31  Canada  None
# 754     2011     2011-01-01   2011-12-31  Canada  None
# 755     2011     2011-01-01   2011-12-31  Canada  None
# 756     2012     2012-01-01   2012-12-31  Canada  None
# 757     2012     2012-01-01   2012-12-31  Canada  None
#
#                                                  Value      UOM  UOM_ID  \
# 753  Present value calculation, timber stocks, meth...  Dollars      81
# 754  Present value calculation, timber stocks, meth...  Dollars      81
# 755  Present value calculation, timber stocks, meth...  Dollars      81
# 756  Present value calculation, timber stocks, meth...  Dollars      81
# 757  Present value calculation, timber stocks, meth...  Dollars      81
#
#     SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE   VALUE_1 STATUS SYMBOL  \
# 753      millions          6  v3822241        1.2  124971.2   None   None
# 754      millions          6  v3822240        1.1  120498.5   None   None
# 755      millions          6  v3822241        1.2  120498.5   None   None
# 756      millions          6  v3822240        1.1  113132.6   None   None
# 757      millions          6  v3822241        1.2  113132.6   None   None
#
#     TERMINATED  DECIMALS
# 753       None         1
# 754       None         1
# 755       None         1
# 756       None         1
# 757       None         1

# %%
files = glob.glob("/data/tables/output/en/june_20_2025/*.parquet")

# %%
duplicate_column_names = {}
for file in files:
    # Open the Parquet file metadata
    dataset = pq.ParquetFile(file)
    # Get the column names
    column_names = [x.upper() for x in dataset.schema.names]
    count_of_column_names = [x for x in column_names if column_names.count(x) > 1]
    if count_of_column_names:
        product_id = file.split('/')[-1].split('.parquet')[0]
        duplicate_column_names[product_id] = list(set(count_of_column_names))

pprint.pprint(duplicate_column_names)
# Out:
# {'10100164': ['VALUE'],
#  '13100904': ['STATUS'],
#  '23100049': ['VALUE'],
#  '23100050': ['VALUE'],
#  '23100268': ['STATUS'],
#  '36100374': ['VALUE'],
#  '36100396': ['VALUE'],
#  '36100397': ['VALUE'],
#  '36100658': ['VALUE'],
#  '38100104': ['VALUE'],
#  '38100105': ['VALUE']}

# %%
for file in files:
    # Open the Parquet file metadata
    dataset = pq.VALUEParquetFile(file)
    # Get the column names
    column_names = dataset.schema.names
    has_dot = ['.' in x for x in column_names if '.' in x]
    if has_dot:
        print(file)
        print(column_names)
# Out:
# /data/tables/output/en/june_20_2025/11100235.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'North American Product Classification System (NAPCS) Canada 2012 Version 1.1', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# /data/tables/output/en/june_20_2025/11100236.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'North American Product Classification System (NAPCS) Canada 2012 Version 1.1', 'North American Industry Classification System (NAICS)', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# /data/tables/output/en/june_20_2025/13100902.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age group in 2019', 'Gender in 2019', 'Status.1', 'Domains', 'Characteristics', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# /data/tables/output/en/june_20_2025/20100014.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'North American Product Classification System (NAPCS) Canada 2012 Version 1.2', 'Financial variables', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# /data/tables/output/en/june_20_2025/20100015.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'North American Product Classification System (NAPCS) Canada 2022 Version 1.0', 'Financial variables', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# /data/tables/output/en/june_20_2025/23100313.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Distance-capacity public transit service area', 'Location', 'Gender', 'Demographic and socio-economic', 'Sustainable Development Goals (SDGs) 11.2.1 indicator', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# /data/tables/output/en/june_20_2025/98100478.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Language spoken most often at home (11)', 'Coordinate', 'Place of work status (7):Total - Place of work status[1]', 'Symbol', 'Place of work status (7):Worked at home[2]', 'Symbol.1', 'Place of work status (7):Worked outside Canada[3]', 'Symbol.2', 'Place of work status (7):No fixed workplace address[4]', 'Symbol.3', 'Place of work status (7):Usual place of work[5]', 'Symbol.4', 'Place of work status (7):Usual place of work - Inside province/territory of residence[6]', 'Symbol.5', 'Place of work status (7):Usual place of work - Outside province/territory of residence[7]', 'Symbol.6']
# /data/tables/output/en/june_20_2025/98100479.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Time leaving for work (7)', 'Commuting duration (7)', 'Main mode of commuting (21)', 'Coordinate', 'Place of work status (3A):Total - Place of work status[1]', 'Symbol', 'Place of work status (3A):No fixed workplace address[2]', 'Symbol.1', 'Place of work status (3A):Usual place of work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100480.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Time leaving for work (7)', 'Commuting duration (7)', 'Main mode of commuting (21)', 'Coordinate', 'Place of work status (3A):Total - Place of work status[1]', 'Symbol', 'Place of work status (3A):No fixed workplace address[2]', 'Symbol.1', 'Place of work status (3A):Usual place of work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100481.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3)', 'Highest certificate, diploma or degree (16)', 'Coordinate', 'Place of work status (7):Total - Place of work status[1]', 'Symbol', 'Place of work status (7):Worked at home[2]', 'Symbol.1', 'Place of work status (7):Worked outside Canada[3]', 'Symbol.2', 'Place of work status (7):No fixed workplace address[4]', 'Symbol.3', 'Place of work status (7):Usual place of work[5]', 'Symbol.4', 'Place of work status (7):Usual place of work - Inside province/territory of residence[6]', 'Symbol.5', 'Place of work status (7):Usual place of work - Outside province/territory of residence[7]', 'Symbol.6']
# /data/tables/output/en/june_20_2025/98100482.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3)', 'Highest certificate, diploma or degree (16)', 'Coordinate', 'Place of work status (7):Total - Place of work status[1]', 'Symbol', 'Place of work status (7):Worked at home[2]', 'Symbol.1', 'Place of work status (7):Worked outside Canada[3]', 'Symbol.2', 'Place of work status (7):No fixed workplace address[4]', 'Symbol.3', 'Place of work status (7):Usual place of work[5]', 'Symbol.4', 'Place of work status (7):Usual place of work - Inside province/territory of residence[6]', 'Symbol.5', 'Place of work status (7):Usual place of work - Outside province/territory of residence[7]', 'Symbol.6']
# /data/tables/output/en/june_20_2025/98100485.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Labour force status (8)', 'Age (15A)', 'Coordinate', 'Gender (3):Total - Gender[1]', 'Symbol', 'Gender (3):Men+[2]', 'Symbol.1', 'Gender (3):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100486.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Labour force status (8)', 'Age (15A)', 'Coordinate', 'Gender (3):Total - Gender[1]', 'Symbol', 'Gender (3):Men+[2]', 'Symbol.1', 'Gender (3):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100491.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Work activity during the reference year (4A)', 'Age (15A)', 'Gender (3)', 'Industry - Sectors - North American Industry Classification System (NAICS) 2017 (21)', 'Coordinate', 'Place of work status (3):Total - Place of work status[1]', 'Symbol', 'Place of work status (3):Worked at home[2]', 'Symbol.1', 'Place of work status (3):Usual place of work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100492.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Work activity during the reference year (4A)', 'Age (15A)', 'Gender (3)', 'Industry - Sectors - North American Industry Classification System (NAICS) 2017 (21)', 'Coordinate', 'Place of work status (3):Total - Place of work status[1]', 'Symbol', 'Place of work status (3):Worked at home[2]', 'Symbol.1', 'Place of work status (3):Usual place of work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100493.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Work activity during the reference year (4A)', 'Age (15A)', 'Gender (3)', 'Occupation - Broad category - National Occupational Classification (NOC) 2021 (11)', 'Coordinate', 'Place of work status (3):Total - Place of work status[1]', 'Symbol', 'Place of work status (3):Worked at home[2]', 'Symbol.1', 'Place of work status (3):Usual place of work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100494.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Work activity during the reference year (4A)', 'Age (15A)', 'Gender (3)', 'Occupation - Broad category - National Occupational Classification (NOC) 2021 (11)', 'Coordinate', 'Place of work status (3):Total - Place of work status[1]', 'Symbol', 'Place of work status (3):Worked at home[2]', 'Symbol.1', 'Place of work status (3):Usual place of work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100495.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Place of work status (3)', 'Coordinate', 'Total income groups (18):Total - Total income[1]', 'Symbol', 'Total income groups (18):Without total income[2]', 'Symbol.1', 'Total income groups (18):With total income[3]', 'Symbol.2', 'Total income groups (18):Under $10,000 (including loss)[4]', 'Symbol.3', 'Total income groups (18):$10,000 to $19,999[5]', 'Symbol.4', 'Total income groups (18):$20,000 to $29,999[6]', 'Symbol.5', 'Total income groups (18):$30,000 to $39,999[7]', 'Symbol.6', 'Total income groups (18):$40,000 to $49,999[8]', 'Symbol.7', 'Total income groups (18):$50,000 to $59,999[9]', 'Symbol.8', 'Total income groups (18):$60,000 to $69,999[10]', 'Symbol.9', 'Total income groups (18):$70,000 to $79,999[11]', 'Symbol.10', 'Total income groups (18):$80,000 to $89,999[12]', 'Symbol.11', 'Total income groups (18):$90,000 to $99,999[13]', 'Symbol.12', 'Total income groups (18):$100,000 and over[14]', 'Symbol.13', 'Total income groups (18):$100,000 to $149,999[15]', 'Symbol.14', 'Total income groups (18):$150,000 and over[16]', 'Symbol.15', 'Total income groups (18):Median total income ($)[17]', 'Symbol.16', 'Total income groups (18):Average total income ($)[18]', 'Symbol.17']
# /data/tables/output/en/june_20_2025/98100496.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Place of work status (3)', 'Coordinate', 'Total income groups (18):Total - Total income[1]', 'Symbol', 'Total income groups (18):Without total income[2]', 'Symbol.1', 'Total income groups (18):With total income[3]', 'Symbol.2', 'Total income groups (18):Under $10,000 (including loss)[4]', 'Symbol.3', 'Total income groups (18):$10,000 to $19,999[5]', 'Symbol.4', 'Total income groups (18):$20,000 to $29,999[6]', 'Symbol.5', 'Total income groups (18):$30,000 to $39,999[7]', 'Symbol.6', 'Total income groups (18):$40,000 to $49,999[8]', 'Symbol.7', 'Total income groups (18):$50,000 to $59,999[9]', 'Symbol.8', 'Total income groups (18):$60,000 to $69,999[10]', 'Symbol.9', 'Total income groups (18):$70,000 to $79,999[11]', 'Symbol.10', 'Total income groups (18):$80,000 to $89,999[12]', 'Symbol.11', 'Total income groups (18):$90,000 to $99,999[13]', 'Symbol.12', 'Total income groups (18):$100,000 and over[14]', 'Symbol.13', 'Total income groups (18):$100,000 to $149,999[15]', 'Symbol.14', 'Total income groups (18):$150,000 and over[16]', 'Symbol.15', 'Total income groups (18):Median total income ($)[17]', 'Symbol.16', 'Total income groups (18):Average total income ($)[18]', 'Symbol.17']
# /data/tables/output/en/june_20_2025/98100497.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Place of work status (3)', 'Coordinate', 'Employment income groups (18):Total - Employment income[1]', 'Symbol', 'Employment income groups (18):Without employment income[2]', 'Symbol.1', 'Employment income groups (18):With employment income[3]', 'Symbol.2', 'Employment income groups (18):Percentage with employment income[4]', 'Symbol.3', 'Employment income groups (18):Under $5,000 (including loss)[5]', 'Symbol.4', 'Employment income groups (18):$5,000 to $9,999[6]', 'Symbol.5', 'Employment income groups (18):$10,000 to $19,999[7]', 'Symbol.6', 'Employment income groups (18):$20,000 to $29,999[8]', 'Symbol.7', 'Employment income groups (18):$30,000 to $39,999[9]', 'Symbol.8', 'Employment income groups (18):$40,000 to $49,999[10]', 'Symbol.9', 'Employment income groups (18):$50,000 to $59,999[11]', 'Symbol.10', 'Employment income groups (18):$60,000 to $69,999[12]', 'Symbol.11', 'Employment income groups (18):$70,000 to $79,999[13]', 'Symbol.12', 'Employment income groups (18):$80,000 to $89,999[14]', 'Symbol.13', 'Employment income groups (18):$90,000 to $99,999[15]', 'Symbol.14', 'Employment income groups (18):$100,000 and over[16]', 'Symbol.15', 'Employment income groups (18):Median employment income ($)[17]', 'Symbol.16', 'Employment income groups (18):Average employment income ($)[18]', 'Symbol.17']
# /data/tables/output/en/june_20_2025/98100498.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Place of work status (3)', 'Coordinate', 'Employment income groups (18):Total - Employment income[1]', 'Symbol', 'Employment income groups (18):Without employment income[2]', 'Symbol.1', 'Employment income groups (18):With employment income[3]', 'Symbol.2', 'Employment income groups (18):Percentage with employment income[4]', 'Symbol.3', 'Employment income groups (18):Under $5,000 (including loss)[5]', 'Symbol.4', 'Employment income groups (18):$5,000 to $9,999[6]', 'Symbol.5', 'Employment income groups (18):$10,000 to $19,999[7]', 'Symbol.6', 'Employment income groups (18):$20,000 to $29,999[8]', 'Symbol.7', 'Employment income groups (18):$30,000 to $39,999[9]', 'Symbol.8', 'Employment income groups (18):$40,000 to $49,999[10]', 'Symbol.9', 'Employment income groups (18):$50,000 to $59,999[11]', 'Symbol.10', 'Employment income groups (18):$60,000 to $69,999[12]', 'Symbol.11', 'Employment income groups (18):$70,000 to $79,999[13]', 'Symbol.12', 'Employment income groups (18):$80,000 to $89,999[14]', 'Symbol.13', 'Employment income groups (18):$90,000 to $99,999[15]', 'Symbol.14', 'Employment income groups (18):$100,000 and over[16]', 'Symbol.15', 'Employment income groups (18):Median employment income ($)[17]', 'Symbol.16', 'Employment income groups (18):Average employment income ($)[18]', 'Symbol.17']
# /data/tables/output/en/june_20_2025/98100499.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Language spoken most often at home (11)', 'Coordinate', 'Place of work status (5B):Total - Place of work status[1]', 'Symbol', 'Place of work status (5B):Worked at home[2]', 'Symbol.1', 'Place of work status (5B):Usual place of work[3]', 'Symbol.2', 'Place of work status (5B):Usual place of work - Inside province/territory of residence[4]', 'Symbol.3', 'Place of work status (5B):Usual place of work - Outside province/territory of residence[5]', 'Symbol.4']
# /data/tables/output/en/june_20_2025/98100500.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Language spoken most often at home (11)', 'Coordinate', 'Place of work status (5B):Total - Place of work status[1]', 'Symbol', 'Place of work status (5B):Worked at home[2]', 'Symbol.1', 'Place of work status (5B):Usual place of work[3]', 'Symbol.2', 'Place of work status (5B):Usual place of work - Inside province/territory of residence[4]', 'Symbol.3', 'Place of work status (5B):Usual place of work - Outside province/territory of residence[5]', 'Symbol.4']
# /data/tables/output/en/june_20_2025/98100503.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Time arriving at work (16)', 'Main mode of commuting (21)', 'Coordinate', 'Commuting duration (7):Total - Commuting duration[1]', 'Symbol', 'Commuting duration (7):Less than 15 minutes[2]', 'Symbol.1', 'Commuting duration (7):15 to 29 minutes[3]', 'Symbol.2', 'Commuting duration (7):30 to 44 minutes[4]', 'Symbol.3', 'Commuting duration (7):45 to 59 minutes[5]', 'Symbol.4', 'Commuting duration (7):60 minutes and over[6]', 'Symbol.5', 'Commuting duration (7):Average commuting duration (in minutes)[7]', 'Symbol.6']
# /data/tables/output/en/june_20_2025/98100504.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Time arriving at work (16)', 'Main mode of commuting (21)', 'Coordinate', 'Commuting duration (7):Total - Commuting duration[1]', 'Symbol', 'Commuting duration (7):Less than 15 minutes[2]', 'Symbol.1', 'Commuting duration (7):15 to 29 minutes[3]', 'Symbol.2', 'Commuting duration (7):30 to 44 minutes[4]', 'Symbol.3', 'Commuting duration (7):45 to 59 minutes[5]', 'Symbol.4', 'Commuting duration (7):60 minutes and over[6]', 'Symbol.5', 'Commuting duration (7):Average commuting duration (in minutes)[7]', 'Symbol.6']
# /data/tables/output/en/june_20_2025/98100505.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3)', 'Highest certificate, diploma or degree (16)', 'Coordinate', 'Place of work status (3):Total - Place of work status[1]', 'Symbol', 'Place of work status (3):Worked at home[2]', 'Symbol.1', 'Place of work status (3):Usual place of work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100506.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3)', 'Highest certificate, diploma or degree (16)', 'Coordinate', 'Place of work status (3):Total - Place of work status[1]', 'Symbol', 'Place of work status (3):Worked at home[2]', 'Symbol.1', 'Place of work status (3):Usual place of work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100519.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (9)', 'Knowledge of official languages (5)', 'Highest certificate, diploma or degree (7)', 'Age (5)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100520.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Industry - Sectors - North American Industry Classification System (NAICS) 2017 (21)', 'Occupation - Broad category - National Occupational Classification (NOC) 2021 (11)', 'Age (6B)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100521.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Other language(s) used regularly at work (10)', 'Immigrant status (4)', 'Place of birth (144)', 'Labour force status (2)', 'Statistics (3)', 'Language used most often at work (9)', 'Coordinate', 'First official language spoken (5):Total - First official language spoken[1]', 'Symbol', 'First official language spoken (5):English[2]', 'Symbol.1', 'First official language spoken (5):French[3]', 'Symbol.2', 'First official language spoken (5):English and French[4]', 'Symbol.3', 'First official language spoken (5):Neither English nor French[5]', 'Symbol.4']
# /data/tables/output/en/june_20_2025/98100522.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (9)', 'Age (6B)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100523.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'First official language spoken (5)', 'Place of work census division (296)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100524.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Language spoken most often at home (9)', 'All languages spoken at home (9)', 'Immigrant status and period of immigration (11)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100525.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (9)', 'Occupation - Major group - National Occupational Classification (NOC) 2021 (56)', 'Immigrant status (4)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100526.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (9)', 'Industry - Sectors - North American Industry Classification System (NAICS) 2017 (21)', 'Age (5)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100527.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (9)', 'Industry - Sectors - North American Industry Classification System (NAICS) 2017 (21)', 'Highest certificate, diploma or degree (7)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100528.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (9)', 'Industry - Sectors - North American Industry Classification System (NAICS) 2017 (21)', 'Labour force status (2)', 'Statistics (3)', 'All languages used at work (281)', 'Coordinate', 'Single and multiple responses of language used at work (3):Total - Single and multiple responses of language used at work[1]', 'Symbol', 'Single and multiple responses of language used at work (3):Single responses of language used at work[2]', 'Symbol.1', 'Single and multiple responses of language used at work (3):Multiple responses of language used at work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100529.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (9)', 'Labour force status (2)', 'Statistics (3)', 'All languages used at work (281)', 'Coordinate', 'Single and multiple responses of language used at work (3):Total - Single and multiple responses of language used at work[1]', 'Symbol', 'Single and multiple responses of language used at work (3):Single responses of language used at work[2]', 'Symbol.1', 'Single and multiple responses of language used at work (3):Multiple responses of language used at work[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100530.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Knowledge of official languages (5)', 'Other language(s) used regularly at work (10)', 'Highest certificate, diploma or degree (7)', 'Immigrant status (4)', 'Labour force status (2)', 'Statistics (3)', 'Employment income statistics (7)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100531.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Industry - Groups - North American Industry Classification System (NAICS) 2017 (427)', 'Knowledge of official languages (5)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100532.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Occupation - Unit group - National Occupational Classification (NOC) 2021 (820)', 'Knowledge of official languages (5)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100533.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (9)', 'Language spoken most often at home (9)', 'Knowledge of official languages (5)', 'First official language spoken (5)', 'Labour force status (2)', 'Statistics (3)', 'Other language(s) used regularly at work (10)', 'Coordinate', 'Language used most often at work (9):Total - Language used most often at work[1]', 'Symbol', 'Language used most often at work (9):English[2]', 'Symbol.1', 'Language used most often at work (9):French[3]', 'Symbol.2', 'Language used most often at work (9):Non-official language[4]', 'Symbol.3', 'Language used most often at work (9):English and French[5]', 'Symbol.4', 'Language used most often at work (9):English and non-official language(s)[6]', 'Symbol.5', 'Language used most often at work (9):French and non-official language(s)[7]', 'Symbol.6', 'Language used most often at work (9):English, French and non-official language(s)[8]', 'Symbol.7', 'Language used most often at work (9):Multiple non-official languages[9]', 'Symbol.8']
# /data/tables/output/en/june_20_2025/98100534.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3)', 'Age of child (20)', 'Coordinate', 'Eligibility for instruction in the minority official language (3):Total - Eligibility for instruction in the minority official language[1]', 'Symbol', 'Eligibility for instruction in the minority official language (3):Children eligible for instruction in the minority official language[2]', 'Symbol.1', 'Eligibility for instruction in the minority official language (3):Children not eligible for instruction in the minority official language[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100535.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3)', 'Age of child (20)', 'Coordinate', 'Eligibility for instruction in the minority official language (3):Total - Eligibility for instruction in the minority official language[1]', 'Symbol', 'Eligibility for instruction in the minority official language (3):Children eligible for instruction in the minority official language[2]', 'Symbol.1', 'Eligibility for instruction in the minority official language (3):Children not eligible for instruction in the minority official language[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100536.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Linguistic characteristics of the child (27)', 'Eligibility for instruction in the minority official language by detailed eligibility criteria (29)', 'Coordinate', 'Age of child (4):Total - Age of child[1]', 'Symbol', 'Age of child (4):0 to 4 years[2]', 'Symbol.1', 'Age of child (4):5 to 11 years[3]', 'Symbol.2', 'Age of child (4):12 to 18 years[4]', 'Symbol.3']
# /data/tables/output/en/june_20_2025/98100537.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Linguistic characteristics of the child (27)', 'Eligibility for instruction in the minority official language by detailed eligibility criteria (29)', 'Coordinate', 'Age of child (4):Total - Age of child[1]', 'Symbol', 'Age of child (4):0 to 4 years[2]', 'Symbol.1', 'Age of child (4):5 to 11 years[3]', 'Symbol.2', 'Age of child (4):12 to 18 years[4]', 'Symbol.3']
# /data/tables/output/en/june_20_2025/98100538.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Number. of years of primary schooling in an English-language school in Canada for residents of Quebec (15)', 'Number of years of secondary schooling in an English-language school in Canada for residents of Quebec (10)', 'Age (7A)', 'Gender (3)', 'Primary or secondary schooling in an English-language school in Canada by residents of Quebec (6)', 'Coordinate', 'Mother tongue (11):Total - Mother tongue[1]', 'Symbol', 'Mother tongue (11):English[2]', 'Symbol.1', 'Mother tongue (11):French[3]', 'Symbol.2', 'Mother tongue (11):Non-official language[4]', 'Symbol.3', 'Mother tongue (11):Indigenous[5]', 'Symbol.4', 'Mother tongue (11):Non-Indigenous[6]', 'Symbol.5', 'Mother tongue (11):English and French[7]', 'Symbol.6', 'Mother tongue (11):English and non-official language(s)[8]', 'Symbol.7', 'Mother tongue (11):French and non-official language(s)[9]', 'Symbol.8', 'Mother tongue (11):English, French and non-official language(s)[10]', 'Symbol.9', 'Mother tongue (11):Multiple non-official languages[11]', 'Symbol.10']
# /data/tables/output/en/june_20_2025/98100539.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Mother tongue (11)', 'Age (7A)', 'Gender (3)', 'Primary or secondary schooling in French in Canada by residents of Canada outside Quebec (3)', 'Coordinate', 'Type of French program attended in Canada by residents of Canada outside Quebec (6):Total - Type of French program attended in Canada by residents of Canada outside Quebec[1]', 'Symbol', 'Type of French program attended in Canada by residents of Canada outside Quebec (6):Residents of Canada outside Quebec who attended a regular French program in a French-language school or a French immersion program, at the primary or secondary levels in Canada[2]', 'Symbol.1', 'Type of French program attended in Canada by residents of Canada outside Quebec (6):Residents of Canada outside Quebec who attended a regular French program in a French-language school at the primary or secondary levels in Canada[3]', 'Symbol.2', 'Type of French program attended in Canada by residents of Canada outside Quebec (6):Residents of Canada outside Quebec who attended a French immersion program in an English-language school at the primary or secondary levels in Canada[4]', 'Symbol.3', 'Type of French program attended in Canada by residents of Canada outside Quebec (6):Residents of Canada outside Quebec who attended both types of programs in Canada[5]', 'Symbol.4', 'Type of French program attended in Canada by residents of Canada outside Quebec (6):Residents of Canada outside Quebec who did not attend a regular French program in a French-language school or a French immersion program at the primary or secondary levels in Canada[6]', 'Symbol.5']
# /data/tables/output/en/june_20_2025/98100540.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Num.ber of years of primary schooling in a regular French program in a French-language school in Canada for residents of Canada outside Quebec (15)', 'Number of years of secondary schooling in a regular French program in a French-language school in Canada for residents of Canada outside Quebec (10)', 'Age (7A)', 'Type and level of French program attended in Canada (10)', 'Coordinate', 'Mother tongue (11):Total - Mother tongue[1]', 'Symbol', 'Mother tongue (11):English[2]', 'Symbol.1', 'Mother tongue (11):French[3]', 'Symbol.2', 'Mother tongue (11):Non-official language[4]', 'Symbol.3', 'Mother tongue (11):Indigenous[5]', 'Symbol.4', 'Mother tongue (11):Non-Indigenous[6]', 'Symbol.5', 'Mother tongue (11):English and French[7]', 'Symbol.6', 'Mother tongue (11):English and non-official language(s)[8]', 'Symbol.7', 'Mother tongue (11):French and non-official language(s)[9]', 'Symbol.8', 'Mother tongue (11):English, French and non-official language(s)[10]', 'Symbol.9', 'Mother tongue (11):Multiple non-official languages[11]', 'Symbol.10']
# /data/tables/output/en/june_20_2025/98100541.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age of child (20)', 'Gender (3)', 'Eligibility for instruction in the minority official language by detailed eligibility criteria - Detailed total responses (10)', 'Coordinate', 'Eligibility fo instruction in the minority official language by single and multiple eligibility criteria (5):Total - Eligibility for instruction in the minority official language by single and multiple eligibility criteria[1]', 'Symbol', 'Eligibility fo instruction in the minority official language by single and multiple eligibility criteria (5):Children eligible for instruction in the minority official language[2]', 'Symbol.1', 'Eligibility fo instruction in the minority official language by single and multiple eligibility criteria (5):Eligible children who meet a single eligibility criterion[3]', 'Symbol.2', 'Eligibility fo instruction in the minority official language by single and multiple eligibility criteria (5):Eligible children who meet multiple eligibility criteria[4]', 'Symbol.3', 'Eligibility fo instruction in the minority official language by single and multiple eligibility criteria (5):Child not eligible for instruction in the minority official language[5]', 'Symbol.4']
# /data/tables/output/en/june_20_2025/98100543.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age of child (23)', 'Gender (3)', 'Eligibility. for instruction in the minority official language by detailed eligibility criteria (29)', 'Coordinate', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Total – Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s)[1]', 'Symbol', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Total - Children eligible for instruction in the minority official language[2]', 'Symbol.1', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Children eligible for instruction in the minority official language – Canadian citizenship of parent(s) confirmed[3]', 'Symbol.2', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Children eligible for instruction in the minority official language – Canadian citizenship of parent(s) not confirmed[4]', 'Symbol.3', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Children not eligible for instruction in the minority official language[5]', 'Symbol.4']
# /data/tables/output/en/june_20_2025/98100544.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age of child (23)', 'Gender (3)', 'Eligibility. for instruction in the minority official language by detailed eligibility criteria (29)', 'Coordinate', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Total – Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s)[1]', 'Symbol', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Total - Children eligible for instruction in the minority official language[2]', 'Symbol.1', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Children eligible for instruction in the minority official language – Canadian citizenship of parent(s) confirmed[3]', 'Symbol.2', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Children eligible for instruction in the minority official language – Canadian citizenship of parent(s) not confirmed[4]', 'Symbol.3', 'Eligibility for instruction in the minority official language – Variant with Canadian citizenship of parent(s) (5):Children not eligible for instruction in the minority official language[5]', 'Symbol.4']
# /data/tables/output/en/june_20_2025/98100557.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Long-form data quality indicators - Indigenous peoples (10):Indigenous group - Non-response rate[1]', 'Symbol', 'Long-form data quality indicators - Indigenous peoples (10):Indigenous group - Imputation rate[2]', 'Symbol.1', 'Long-form data quality indicators - Indigenous peoples (10):Registered or Treaty Indian status - Non-response rate[3]', 'Symbol.2', 'Long-form data quality indicators - Indigenous peoples (10):Registered or Treaty Indian status - Imputation rate[4]', 'Symbol.3', 'Long-form data quality indicators - Indigenous peoples (10):Membership in a First Nation or Indian band - Non-response rate[5]', 'Symbol.4', 'Long-form data quality indicators - Indigenous peoples (10):Membership in a First Nation or Indian band - Imputation rate[6]', 'Symbol.5', 'Long-form data quality indicators - Indigenous peoples (10):Membership in a Métis organization or Settlement - Non-response rate[7]', 'Symbol.6', 'Long-form data quality indicators - Indigenous peoples (10):Membership in a Métis organization or Settlement - Imputation rate[8]', 'Symbol.7', 'Long-form data quality indicators - Indigenous peoples (10):Enrollment under an Inuit land claims agreement - Non-response rate[9]', 'Symbol.8', 'Long-form data quality indicators - Indigenous peoples (10):Enrollment under an Inuit land claims agreement - Imputation rate[10]', 'Symbol.9']
# /data/tables/output/en/june_20_2025/98100558.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Long-form data quality indicators - Indigenous peoples (10):Indigenous group - Non-response rate[1]', 'Symbol', 'Long-form data quality indicators - Indigenous peoples (10):Indigenous group - Imputation rate[2]', 'Symbol.1', 'Long-form data quality indicators - Indigenous peoples (10):Registered or Treaty Indian status - Non-response rate[3]', 'Symbol.2', 'Long-form data quality indicators - Indigenous peoples (10):Registered or Treaty Indian status - Imputation rate[4]', 'Symbol.3', 'Long-form data quality indicators - Indigenous peoples (10):Membership in a First Nation or Indian band - Non-response rate[5]', 'Symbol.4', 'Long-form data quality indicators - Indigenous peoples (10):Membership in a First Nation or Indian band - Imputation rate[6]', 'Symbol.5', 'Long-form data quality indicators - Indigenous peoples (10):Membership in a Métis organization or Settlement - Non-response rate[7]', 'Symbol.6', 'Long-form data quality indicators - Indigenous peoples (10):Membership in a Métis organization or Settlement - Imputation rate[8]', 'Symbol.7', 'Long-form data quality indicators - Indigenous peoples (10):Enrollment under an Inuit land claims agreement - Non-response rate[9]', 'Symbol.8', 'Long-form data quality indicators - Indigenous peoples (10):Enrollment under an Inuit land claims agreement - Imputation rate[10]', 'Symbol.9']
# /data/tables/output/en/june_20_2025/98100559.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Long-form data quality indicators – Housing characteristics (20):Tenure - Non-response rate[1]', 'Symbol', 'Long-form data quality indicators – Housing characteristics (20):Tenure - Imputation rate[2]', 'Symbol.1', 'Long-form data quality indicators – Housing characteristics (20):Condominium status - Non-response rate[3]', 'Symbol.2', 'Long-form data quality indicators – Housing characteristics (20):Condominium status - Imputation rate[4]', 'Symbol.3', 'Long-form data quality indicators – Housing characteristics (20):Number of rooms - Non-response rate[5]', 'Symbol.4', 'Long-form data quality indicators – Housing characteristics (20):Number of rooms - Imputation rate[6]', 'Symbol.5', 'Long-form data quality indicators – Housing characteristics (20):Number of bedrooms - Non-response rate[7]', 'Symbol.6', 'Long-form data quality indicators – Housing characteristics (20):Number of bedrooms - Imputation rate[8]', 'Symbol.7', 'Long-form data quality indicators – Housing characteristics (20):Period of construction - Non-response rate[9]', 'Symbol.8', 'Long-form data quality indicators – Housing characteristics (20):Period of construction - Imputation rate[10]', 'Symbol.9', 'Long-form data quality indicators – Housing characteristics (20):Dwelling condition - Non-response rate[11]', 'Symbol.10', 'Long-form data quality indicators – Housing characteristics (20):Dwelling condition - Imputation rate[12]', 'Symbol.11', 'Long-form data quality indicators – Housing characteristics (20):Rent monthly cash - Non-response rate[13]', 'Symbol.12', 'Long-form data quality indicators – Housing characteristics (20):Rent monthly cash - Imputation rate[14]', 'Symbol.13', 'Long-form data quality indicators – Housing characteristics (20):Monthly mortgage payments - Non-response rate[15]', 'Symbol.14', 'Long-form data quality indicators – Housing characteristics (20):Monthly mortgage payments - Imputation rate[16]', 'Symbol.15', 'Long-form data quality indicators – Housing characteristics (20):Value (owner estimated) - Non-response rate[17]', 'Symbol.16', 'Long-form data quality indicators – Housing characteristics (20):Value (owner estimated) - Imputation rate[18]', 'Symbol.17', 'Long-form data quality indicators – Housing characteristics (20):Monthly use or occupancy payment for dwelling - Non-response rate[19]', 'Symbol.18', 'Long-form data quality indicators – Housing characteristics (20):Monthly use or occupancy payment for dwelling - Imputation rate[20]', 'Symbol.19']
# /data/tables/output/en/june_20_2025/98100560.parquet
# ...
# /data/tables/output/en/june_20_2025/98100006.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Census metropolitan areas and census agglomerations, by population centres and rural areas (718)', 'Coordinate', 'Population and land area (2): Population, 2021 [1]', 'Symbols', 'Population and land area (2): Land area in square kilometres, 2021 [2]', 'Symbols.1']
# /data/tables/output/en/june_20_2025/98100007.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (13): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (13): Population, 2016 [2]', 'Symbols.1', 'Population and dwelling counts (13): Population percentage change, 2016 to 2021 [3]', 'Symbols.2', 'Population and dwelling counts (13): Total private dwellings, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (13): Total private dwellings, 2016 [5]', 'Symbols.4', 'Population and dwelling counts (13): Total private dwellings percentage change, 2016 to 2021 [6]', 'Symbols.5', 'Population and dwelling counts (13): Private dwellings occupied by usual residents, 2021 [7]', 'Symbols.6', 'Population and dwelling counts (13): Private dwellings occupied by usual residents, 2016 [8]', 'Symbols.7', 'Population and dwelling counts (13): Private dwellings occupied by usual residents percentage change, 2016 to 2021 [9]', 'Symbols.8', 'Population and dwelling counts (13): Land area in square kilometres, 2021 [10]', 'Symbols.9', 'Population and dwelling counts (13): Population density per square kilometre, 2021 [11]', 'Symbols.10', 'Population and dwelling counts (13): National population rank, 2021 [12]', 'Symbols.11', 'Population and dwelling counts (13): Province/territory population rank, 2021 [13]', 'Symbols.12']
# /data/tables/output/en/june_20_2025/98100008.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population centre size groups (6): Total population [1]', 'Symbols', 'Population centre size groups (6): Total population centre size groups [2]', 'Symbols.1', 'Population centre size groups (6): Population centre size group (100,000 and over) [3]', 'Symbols.2', 'Population centre size groups (6): Population centre size group (30,000 to 99,999) [4]', 'Symbols.3', 'Population centre size groups (6): Population centre size group (less than 30,000) [5]', 'Symbols.4', 'Population centre size groups (6): Total rural population [6]', 'Symbols.5']
# /data/tables/output/en/june_20_2025/98100009.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (7): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (7): Population, 2016 [2]', 'Symbols.1', 'Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]', 'Symbols.2', 'Population and dwelling counts (7): Total private dwellings, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]', 'Symbols.4', 'Population and dwelling counts (7): Land area in square kilometres, 2021 [6]', 'Symbols.5', 'Population and dwelling counts (7): Population density per square kilometre, 2021 [7]', 'Symbols.6']
# /data/tables/output/en/june_20_2025/98100010.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (7): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (7): Population, 2016 [2]', 'Symbols.1', 'Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]', 'Symbols.2', 'Population and dwelling counts (7): Total private dwellings, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]', 'Symbols.4', 'Population and dwelling counts (7): Land area in square kilometres, 2021 [6]', 'Symbols.5', 'Population and dwelling counts (7): Population density per square kilometre, 2021 [7]', 'Symbols.6']
# /data/tables/output/en/june_20_2025/98100011.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (7): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (7): Population, 2016 [2]', 'Symbols.1', 'Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]', 'Symbols.2', 'Population and dwelling counts (7): Total private dwellings, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]', 'Symbols.4', 'Population and dwelling counts (7): Land area in square kilometres, 2021 [6]', 'Symbols.5', 'Population and dwelling counts (7): Population density per square kilometre, 2021 [7]', 'Symbols.6']
# /data/tables/output/en/june_20_2025/98100012.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (7): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (7): Population, 2016 [2]', 'Symbols.1', 'Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]', 'Symbols.2', 'Population and dwelling counts (7): Total private dwellings, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]', 'Symbols.4', 'Population and dwelling counts (7): Land area in square kilometres, 2021 [6]', 'Symbols.5', 'Population and dwelling counts (7): Population density per square kilometre, 2021 [7]', 'Symbols.6']
# /data/tables/output/en/june_20_2025/98100013.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (7): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (7): Population, 2016 [2]', 'Symbols.1', 'Population and dwelling counts (7): Population percentage change, 2016 to 2021 [3]', 'Symbols.2', 'Population and dwelling counts (7): Total private dwellings, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (7): Private dwellings occupied by usual residents, 2021 [5]', 'Symbols.4', 'Population and dwelling counts (7): Land area in square kilometres, 2021 [6]', 'Symbols.5', 'Population and dwelling counts (7): Population density per square kilometre, 2021 [7]', 'Symbols.6']
# /data/tables/output/en/june_20_2025/98100014.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (13): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (13): Population, 2016 [2]', 'Symbols.1', 'Population and dwelling counts (13): Population percentage change, 2016 to 2021 [3]', 'Symbols.2', 'Population and dwelling counts (13): Total private dwellings, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (13): Private dwellings occupied by usual residents, 2021 [5]', 'Symbols.4', 'Population and dwelling counts (13): Land area in square kilometres, 2021 [6]', 'Symbols.5', 'Population and dwelling counts (13): Population density per square kilometre, 2021 [7]', 'Symbols.6']
# /data/tables/output/en/june_20_2025/98100015.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (5): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (5): Total private dwellings, 2021 [2]', 'Symbols.1', 'Population and dwelling counts (5): Private dwellings occupied by usual residents, 2021 [3]', 'Symbols.2', 'Population and dwelling counts (5): Land area in square kilometres, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (5): Population density per square kilometre, 2021 [5]', 'Symbols.4']
# /data/tables/output/en/june_20_2025/98100016.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Statistical Area Classification (SAC)', 'Coordinate', 'Population and dwelling counts (3): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (3): Total private dwellings, 2021 [2]', 'Symbols.1', 'Population and dwelling counts (3): Private dwellings occupied by usual residents, 2021 [3]', 'Symbols.2']
# /data/tables/output/en/june_20_2025/98100017.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Census year', 'Coordinate', 'Population and dwelling counts (4): Population, count [1]', 'Symbols', 'Population and dwelling counts (4): Population, intercensal growth (percent) [2]', 'Symbols.1', 'Population and dwelling counts (4): Private dwellings occupied by usual residents, count (9) [3]', 'Symbols.2', 'Population and dwelling counts (4): Private dwellings occupied by usual residents, intercensal growth (percent) [4]', 'Symbols.3']
# /data/tables/output/en/june_20_2025/98100018.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (11): Population, 2021 [1]', 'Symbols', 'Population and dwelling counts (11): Population, 2016 [2]', 'Symbols.1', 'Population and dwelling counts (11): Population percentage change, 2016 to 2021 [3]', 'Symbols.2', 'Population and dwelling counts (11): Total private dwellings, 2021 [4]', 'Symbols.3', 'Population and dwelling counts (11): Total private dwellings, 2016 [5]', 'Symbols.4', 'Population and dwelling counts (11): Total private dwellings percentage change, 2016 to 2021 [6]', 'Symbols.5', 'Population and dwelling counts (11): Private dwellings occupied by usual residents, 2021 [7]', 'Symbols.6', 'Population and dwelling counts (11): Private dwellings occupied by usual residents, 2016 [8]', 'Symbols.7', 'Population and dwelling counts (11): Private dwellings occupied by usual residents percentage change, 2016 to 2021 [9]', 'Symbols.8', 'Population and dwelling counts (11): Land area in square kilometres, 2021 [10]', 'Symbols.9', 'Population and dwelling counts (11): Population density per square kilometre, 2021 [11]', 'Symbols.10']
# /data/tables/output/en/june_20_2025/98100019.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Coordinate', 'Population and dwelling counts (3):Population, 2021[1]', 'Symbol', 'Population and dwelling counts (3):Total private dwellings, 2021[2]', 'Symbol.1', 'Population and dwelling counts (3):Private dwellings occupied by usual residents, 2021[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100020.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Census year (2)', 'Age (in single years), average age and median age (128)', 'Coordinate', 'Gender (3a):Total - Gender[1]', 'Symbol', 'Gender (3a):Men+[2]', 'Symbol.1', 'Gender (3a):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100021.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Census year (2)', 'Age (in single years), average age and median age (128)', 'Coordinate', 'Gender (3a):Total - Gender[1]', 'Symbol', 'Gender (3a):Men+[2]', 'Symbol.1', 'Gender (3a):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100022.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Census year (2)', 'Age (in single years), average age and median age (128)', 'Coordinate', 'Gender (3a):Total - Gender[1]', 'Symbol', 'Gender (3a):Men+[2]', 'Symbol.1', 'Gender (3a):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100023.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age (in single years), average age and median age (128)', 'Coordinate', 'Gender (3):Total - Gender[1]', 'Symbol', 'Gender (3):Men+[2]', 'Symbol.1', 'Gender (3):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100024.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age (in single years), average age and median age (128)', 'Coordinate', 'Gender (3):Total - Gender[1]', 'Symbol', 'Gender (3):Men+[2]', 'Symbol.1', 'Gender (3):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100025.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age (in single years), average age and median age (128)', 'Coordinate', 'Gender (3):Total - Gender[1]', 'Symbol', 'Gender (3):Men+[2]', 'Symbol.1', 'Gender (3):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100026.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age (in single years), average age and median age (128)', 'Coordinate', 'Gender (3):Total - Gender[1]', 'Symbol', 'Gender (3):Men+[2]', 'Symbol.1', 'Gender (3):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100027.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Age (in single years), average age and median age (128)', 'Coordinate', 'Gender (3):Total - Gender[1]', 'Symbol', 'Gender (3):Men+[2]', 'Symbol.1', 'Gender (3):Women+[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100030.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3a)', 'Broad age groups (5)', 'Coordinate', 'View:2021 counts[1]', 'Symbol', 'View:% distribution 2021[2]', 'Symbol.1', 'View:2016 counts[3]', 'Symbol.2', 'View:% distribution 2016[4]', 'Symbol.3']
# /data/tables/output/en/june_20_2025/98100031.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3a)', 'Broad age groups (5)', 'Coordinate', 'View:2021 counts[1]', 'Symbol', 'View:% distribution 2021[2]', 'Symbol.1', 'View:2016 counts[3]', 'Symbol.2', 'View:% distribution 2016[4]', 'Symbol.3']
# /data/tables/output/en/june_20_2025/98100032.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3a)', 'Broad age groups (5)', 'Coordinate', 'View:2021 counts[1]', 'Symbol', 'View:% distribution 2021[2]', 'Symbol.1', 'View:2016 counts[3]', 'Symbol.2', 'View:% distribution 2016[4]', 'Symbol.3']
# /data/tables/output/en/june_20_2025/98100033.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Gender (3a)', 'Census year (25)', 'Coordinate', 'Broad age groups (5):Total - Age[1]', 'Symbol', 'Broad age groups (5):0 to 14 years[2]', 'Symbol.1', 'Broad age groups (5):15 to 64 years[3]', 'Symbol.2', 'Broad age groups (5):65 years and over[4]', 'Symbol.3', 'Broad age groups (5):Average age[5]', 'Symbol.4']
# /data/tables/output/en/june_20_2025/98100034.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Broad age groups (5)', 'Coordinate', 'Sex (3):Total - Sex[1]', 'Symbol', 'Sex (3):Male[2]', 'Symbol.1', 'Sex (3):Female[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100035.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Broad age groups (5)', 'Coordinate', 'Sex (3):Total - Sex[1]', 'Symbol', 'Sex (3):Male[2]', 'Symbol.1', 'Sex (3):Female[3]', 'Symbol.2']
# /data/tables/output/en/june_20_2025/98100036.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Broad age groups (3)', 'Coordinate', 'Gender (8):Total - Gender[1]', 'Symbol', 'Gender (8):Cisgender persons[2]', 'Symbol.1', 'Gender (8):Cisgender men[3]', 'Symbol.2', 'Gender (8):Cisgender women[4]', 'Symbol.3', 'Gender (8):Transgender persons[5]', 'Symbol.4', 'Gender (8):Transgender men[6]', 'Symbol.5', 'Gender (8):Transgender women[7]', 'Symbol.6', 'Gender (8):Non-binary persons[8]', 'Symbol.7']
# /data/tables/output/en/june_20_2025/98100037.parquet
# ['REF_DATE', 'REF_START_DATE', 'REF_END_DATE', 'GEO', 'DGUID', 'Broad age groups (3)', 'Coordinate', 'Gender (8):Total - Gender[1]', 'Symbol', 'Gender (8):Cisgender persons[2]', 'Symbol.1', 'Gender (8):Cisgender men[3]', 'Symbol.2', 'Gender (8):Cisgender women[4]', 'Symbol.3', 'Gender (8):Transgender persons[5]', 'Symbol.4', 'Gender (8):Transgender men[6]', 'Symbol.5', 'Gender (8):Transgender women[7]', 'Symbol.6', 'Gender (8):Non-binary persons[8]', 'Symbol.7']
