# %%
import pandas as pd

data_folder="/data/tables"

# %%
"""
tables = pd.read_json('tables.json')
tables_unique = tables.drop_duplicates()
tables_unique.to_json('tables_unique.json', index=False)
"""
# Out:
# "\ntables = pd.read_json('tables.json')\ntables_unique = tables.drop_duplicates()\ntables_unique.to_json('tables_unique.json', index=False)\n"

# %%
tables_unique = pd.read_json('tables_unique.json')

# %%
len(tables_unique)
# Out:
# 12179

# %%
import sqlite3

import buckaroo

con = sqlite3.connect('tables_data.db')

# %%
cur = con.cursor()

cur.executescript("""
-- DROP TABLE IF EXISTS processed;
CREATE TABLE IF NOT EXISTS processed (
  table_id TEXT,
  message TEXT
);

/*
Maps unique dguids to which tables they are found in
*/
-- DROP TABLE IF EXISTS dguid_table_id;
CREATE TABLE IF NOT EXISTS dguid_table_id (
  dguid TEXT,
  table_id TEXT
);
""")

con.commit()

# %%
import time
import aria2p

# initialization, these are the default values
aria2 = aria2p.API(
    aria2p.Client(
        host="http://localhost",
        port=6800,
        secret=""
    )
)

# Helper function to wait for download to finish
def wait_for_download(download):
    while download.is_active:
        print(f"Progress: {download.progress_string()} - {download.status}")
        time.sleep(10)
        download = aria2.get_download(download.gid)  # refresh state
    print(f"Download completed: {download.name} - Status: {download.status}")
    return download

# %%
import os
import json
import re
import requests

def parse_table(table):
    parsed_table = re.sub(r"\D", "", table)[:8]
    return parsed_table

def download_table(table_id):
    print(f"Input table_id {table_id}")
    table_id = parse_table(table_id)
    if len(table_id) == 8:
        print(f"Getting metadata for {table_id}")
    else:
        print(f"productId: {table_id} not length 8")
        return

    metadata_path = f"{data_folder}/{table_id}.json"
    if os.path.exists(metadata_path):
        print(f"Metadata and data for {table_id} already exists")
        return
        
    # Write the metadata to a JSON file
    url = f"https://www150.statcan.gc.ca/t1/wds/rest/getCubeMetadata"
    payload = [{"productId": table_id}]
    response = requests.post(url, json=payload)
    
    if response.status_code == 200:    
        # It can still be a failed search even if it is status_code 200
        response_dict = response.json()[0]

        status = response_dict.get("status")
        if status:
            status_message = response_dict.get("object")
            if status == "FAILED":
                print(status_message)
                return
        
        #if os.path.exists(metadata_path):
        with open(metadata_path, "w") as metadata_fp:
            json.dump(response_dict, metadata_fp)
    else:
        print(f"Failed to request. Status code: {response.status_code}")
        return

    url = f"https://www150.statcan.gc.ca/t1/wds/rest/getFullTableDownloadCSV/{table_id}/en"
    print(f"Getting the download url for {table_id}")
    response_dict = requests.get(url).json()
    status = response_dict.get("status")
    if status:
        status_message = response_dict.get("object")
        
    print(f"Downloading {status_message} to {data_folder}/{table_id}.zip")
    urls = [status_message]
    download = aria2.add_uris(urls, options={"out": f"{table_id}.zip"})
    download = wait_for_download(download)
    """
    response = requests.get(status_message, stream=True, headers={"user-agent": None})
    with open(f"{data_folder}/{table_id}.zip", "wb") as f:
        for chunk in response.iter_content(chunk_size=512):
            if chunk:
                f.write(chunk)
    """

    return table_id

# %%
import zipfile

def process_table(table_id):
    table_path = f"{data_folder}/{table_id}.zip"
    csv_file = f"{table_id}.csv"
    print(f"Processing {table_path}")
    with zipfile.ZipFile(table_path) as myzip:
        with myzip.open(csv_file) as myfile:
            col_names = pd.read_csv(myfile, nrows=0).columns

        # reopen the file or it misses the first row
        with myzip.open(csv_file) as myfile:
            #types_dict = {"VALUE": float}
            #types_dict.update({col: str for col in col_names if col not in types_dict})
            #df = pd.read_csv(myfile, usecols=["DGUID"], dtype=types_dict)
            df = pd.read_csv(myfile, usecols=["DGUID"]).drop_duplicates()

    
    universe_path = f"{data_folder}/universe/{table_id}.parquet"
    print(f"Wrote to {universe_path}")
    df.to_parquet(universe_path, compression="zstd", index=False)

# %%
for record in tables_unique.to_records():
    index, table_id = record
    download_table(table_id)
# Out:
# Input table_id 33-10-0036-01
# Getting metadata for 33100036
# Metadata and data for 33100036 already exists
# Input table_id 13-10-0946-01
# Getting metadata for 13100946
# Metadata and data for 13100946 already exists
# Input table_id 13-10-0959-01
# Getting metadata for 13100959
# Metadata and data for 13100959 already exists
# Input table_id 13-10-0960-01
# Getting metadata for 13100960
# Metadata and data for 13100960 already exists
# Input table_id 23-10-0287-01
# Getting metadata for 23100287
# Metadata and data for 23100287 already exists
# Input table_id 10-10-0139-01
# Getting metadata for 10100139
# Metadata and data for 10100139 already exists
# Input table_id 10-10-0141-01
# Getting metadata for 10100141
# Metadata and data for 10100141 already exists
# Input table_id 11-10-0084-01
# Getting metadata for 11100084
# Metadata and data for 11100084 already exists
# Input table_id 11-10-0085-01
# Getting metadata for 11100085
# Metadata and data for 11100085 already exists
# Input table_id 11-10-0086-01
# Getting metadata for 11100086
# Metadata and data for 11100086 already exists
# Input table_id 34-10-0292-01
# Getting metadata for 34100292
# Metadata and data for 34100292 already exists
# Input table_id 34-10-0292-02
# Getting metadata for 34100292
# Metadata and data for 34100292 already exists
# Input table_id 36-10-0038-01
# Getting metadata for 36100038
# Metadata and data for 36100038 already exists
# Input table_id 36-10-0039-01
# Getting metadata for 36100039
# Metadata and data for 36100039 already exists
# Input table_id 36-10-0412-01
# Getting metadata for 36100412
# Metadata and data for 36100412 already exists
# Input table_id 36-10-0443-01
# Getting metadata for 36100443
# Metadata and data for 36100443 already exists
# Input table_id 36-10-0446-01
# Getting metadata for 36100446
# Metadata and data for 36100446 already exists
# Input table_id 36-10-0454-01
# Getting metadata for 36100454
# Metadata and data for 36100454 already exists
# Input table_id 36-10-0469-01
# Getting metadata for 36100469
# Metadata and data for 36100469 already exists
# Input table_id 36-10-0474-01
# Getting metadata for 36100474
# Metadata and data for 36100474 already exists
# Input table_id 36-10-0485-01
# Getting metadata for 36100485
# Metadata and data for 36100485 already exists
# Input table_id 36-10-0593-01
# Getting metadata for 36100593
# Metadata and data for 36100593 already exists
# Input table_id 32-10-0480-01
# Getting metadata for 32100480
# Metadata and data for 32100480 already exists
# Input table_id 32-10-0481-01
# Getting metadata for 32100481
# Metadata and data for 32100481 already exists
# Input table_id 32-10-0482-01
# Getting metadata for 32100482
# Metadata and data for 32100482 already exists
# Input table_id 32-10-0483-01
# Getting metadata for 32100483
# Metadata and data for 32100483 already exists
# Input table_id 32-10-0484-01
# Getting metadata for 32100484
# Metadata and data for 32100484 already exists
# Input table_id 32-10-0485-01
# Getting metadata for 32100485
# Metadata and data for 32100485 already exists
# Input table_id 18-10-0204-01
# Getting metadata for 18100204
# Metadata and data for 18100204 already exists
# Input table_id 18-10-0204-02
# Getting metadata for 18100204
# Metadata and data for 18100204 already exists
# Input table_id 24-10-0056-01
# Getting metadata for 24100056
# Metadata and data for 24100056 already exists
# Input table_id 24-10-0057-01
# Getting metadata for 24100057
# Metadata and data for 24100057 already exists
# Input table_id 24-10-0058-01
# Getting metadata for 24100058
# Metadata and data for 24100058 already exists
# Input table_id 24-10-0059-01
# Getting metadata for 24100059
# Metadata and data for 24100059 already exists
# Input table_id 32-10-0077-01
# Getting metadata for 32100077
# Metadata and data for 32100077 already exists
# Input table_id 32-10-0110-01
# Getting metadata for 32100110
# Metadata and data for 32100110 already exists
# Input table_id 32-10-0113-01
# Getting metadata for 32100113
# Metadata and data for 32100113 already exists
# Input table_id 32-10-0132-01
# Getting metadata for 32100132
# Metadata and data for 32100132 already exists
# Input table_id 10-10-0135-01
# Getting metadata for 10100135
# Metadata and data for 10100135 already exists
# Input table_id 10-10-0136-01
# Getting metadata for 10100136
# Metadata and data for 10100136 already exists
# Input table_id 10-10-0158-01
# Getting metadata for 10100158
# Metadata and data for 10100158 already exists
# Input table_id 23-10-0001-01
# Getting metadata for 23100001
# Metadata and data for 23100001 already exists
# Input table_id 23-10-0073-01
# Getting metadata for 23100073
# Metadata and data for 23100073 already exists
# Input table_id 23-10-0268-01
# Getting metadata for 23100268
# Metadata and data for 23100268 already exists
# Input table_id 23-10-0272-01
# Getting metadata for 23100272
# Metadata and data for 23100272 already exists
# Input table_id 36-10-0042-01
# Getting metadata for 36100042
# Metadata and data for 36100042 already exists
# Input table_id 36-10-0430-01
# Getting metadata for 36100430
# Metadata and data for 36100430 already exists
# Input table_id 36-10-0431-01
# Getting metadata for 36100431
# Metadata and data for 36100431 already exists
# Input table_id 36-10-0491-01
# Getting metadata for 36100491
# Metadata and data for 36100491 already exists
# Input table_id 38-10-0011-01
# Getting metadata for 38100011
# Metadata and data for 38100011 already exists
# Input table_id 38-10-0015-01
# Getting metadata for 38100015
# Metadata and data for 38100015 already exists
# Input table_id 38-10-0016-01
# Getting metadata for 38100016
# Metadata and data for 38100016 already exists
# Input table_id 38-10-0086-01
# Getting metadata for 38100086
# Metadata and data for 38100086 already exists
# Input table_id 38-10-0144-01
# Getting metadata for 38100144
# Metadata and data for 38100144 already exists
# Input table_id 38-10-0144-02
# Getting metadata for 38100144
# Metadata and data for 38100144 already exists
# Input table_id 38-10-0144-03
# Getting metadata for 38100144
# Metadata and data for 38100144 already exists
# Input table_id 38-10-0154-01
# Getting metadata for 38100154
# Metadata and data for 38100154 already exists
# Input table_id 38-10-0156-01
# Getting metadata for 38100156
# Metadata and data for 38100156 already exists
# Input table_id 38-10-0184-01
# Getting metadata for 38100184
# Metadata and data for 38100184 already exists
# Input table_id 38-10-0185-01
# Getting metadata for 38100185
# Metadata and data for 38100185 already exists
# Input table_id 38-10-0186-01
# Getting metadata for 38100186
# Metadata and data for 38100186 already exists
# Input table_id 38-10-0281-01
# Getting metadata for 38100281
# Metadata and data for 38100281 already exists
# Input table_id 14-10-0017-01
# Getting metadata for 14100017
# Metadata and data for 14100017 already exists
# Input table_id 14-10-0017-02
# Getting metadata for 14100017
# Metadata and data for 14100017 already exists
# Input table_id 14-10-0019-01
# Getting metadata for 14100019
# Metadata and data for 14100019 already exists
# Input table_id 14-10-0021-01
# Getting metadata for 14100021
# Metadata and data for 14100021 already exists
# Input table_id 14-10-0022-01
# Getting metadata for 14100022
# Metadata and data for 14100022 already exists
# Input table_id 14-10-0026-01
# Getting metadata for 14100026
# Metadata and data for 14100026 already exists
# Input table_id 14-10-0028-01
# Getting metadata for 14100028
# Metadata and data for 14100028 already exists
# Input table_id 14-10-0030-01
# Getting metadata for 14100030
# Metadata and data for 14100030 already exists
# Input table_id 14-10-0032-01
# Getting metadata for 14100032
# Metadata and data for 14100032 already exists
# Input table_id 14-10-0034-01
# Getting metadata for 14100034
# Metadata and data for 14100034 already exists
# Input table_id 14-10-0036-01
# Getting metadata for 14100036
# Metadata and data for 14100036 already exists
# Input table_id 14-10-0042-01
# Getting metadata for 14100042
# Metadata and data for 14100042 already exists
# Input table_id 14-10-0045-01
# Getting metadata for 14100045
# Metadata and data for 14100045 already exists
# Input table_id 14-10-0048-01
# Getting metadata for 14100048
# Metadata and data for 14100048 already exists
# Input table_id 14-10-0048-02
# Getting metadata for 14100048
# Metadata and data for 14100048 already exists
# Input table_id 14-10-0050-01
# Getting metadata for 14100050
# Metadata and data for 14100050 already exists
# Input table_id 14-10-0054-01
# Getting metadata for 14100054
# Metadata and data for 14100054 already exists
# Input table_id 14-10-0058-01
# Getting metadata for 14100058
# Metadata and data for 14100058 already exists
# Input table_id 14-10-0063-01
# Getting metadata for 14100063
# Metadata and data for 14100063 already exists
# Input table_id 14-10-0065-01
# Getting metadata for 14100065
# Metadata and data for 14100065 already exists
# Input table_id 14-10-0067-01
# Getting metadata for 14100067
# Metadata and data for 14100067 already exists
# Input table_id 14-10-0069-01
# Getting metadata for 14100069
# Metadata and data for 14100069 already exists
# Input table_id 14-10-0071-01
# Getting metadata for 14100071
# Metadata and data for 14100071 already exists
# Input table_id 14-10-0075-01
# Getting metadata for 14100075
# Metadata and data for 14100075 already exists
# Input table_id 14-10-0077-01
# Getting metadata for 14100077
# Metadata and data for 14100077 already exists
# Input table_id 14-10-0086-01
# Getting metadata for 14100086
# Metadata and data for 14100086 already exists
# Input table_id 14-10-0109-01
# Getting metadata for 14100109
# Metadata and data for 14100109 already exists
# Input table_id 14-10-0117-01
# Getting metadata for 14100117
# Metadata and data for 14100117 already exists
# Input table_id 14-10-0121-01
# Getting metadata for 14100121
# Metadata and data for 14100121 already exists
# Input table_id 14-10-0123-01
# Getting metadata for 14100123
# Metadata and data for 14100123 already exists
# Input table_id 14-10-0125-01
# Getting metadata for 14100125
# Metadata and data for 14100125 already exists
# Input table_id 14-10-0127-01
# Getting metadata for 14100127
# Metadata and data for 14100127 already exists
# Input table_id 14-10-0286-01
# Getting metadata for 14100286
# Metadata and data for 14100286 already exists
# Input table_id 14-10-0286-02
# Getting metadata for 14100286
# Metadata and data for 14100286 already exists
# Input table_id 14-10-0286-03
# Getting metadata for 14100286
# Metadata and data for 14100286 already exists
# Input table_id 14-10-0287-01
# Getting metadata for 14100287
# Metadata and data for 14100287 already exists
# Input table_id 14-10-0287-02
# Getting metadata for 14100287
# Metadata and data for 14100287 already exists
# Input table_id 14-10-0287-03
# Getting metadata for 14100287
# Metadata and data for 14100287 already exists
# Input table_id 13-609-X
# productId: 13609 not length 8
# Input table_id 14-10-0288-01
# Getting metadata for 14100288
# Metadata and data for 14100288 already exists
# Input table_id 14-10-0288-02
# Getting metadata for 14100288
# Metadata and data for 14100288 already exists
# Input table_id 14-10-0289-01
# Getting metadata for 14100289
# Metadata and data for 14100289 already exists
# Input table_id 14-10-0289-02
# Getting metadata for 14100289
# Metadata and data for 14100289 already exists
# Input table_id 14-10-0291-01
# Getting metadata for 14100291
# Metadata and data for 14100291 already exists
# Input table_id 14-10-0291-02
# Getting metadata for 14100291
# Metadata and data for 14100291 already exists
# Input table_id 14-10-0292-01
# Getting metadata for 14100292
# Metadata and data for 14100292 already exists
# Input table_id 14-10-0292-02
# Getting metadata for 14100292
# Metadata and data for 14100292 already exists
# Input table_id 14-10-0310-01
# Getting metadata for 14100310
# Metadata and data for 14100310 already exists
# Input table_id 14-10-0310-02
# Getting metadata for 14100310
# Metadata and data for 14100310 already exists
# Input table_id 14-10-0320-01
# Getting metadata for 14100320
# Metadata and data for 14100320 already exists
# Input table_id 14-10-0320-02
# Getting metadata for 14100320
# Metadata and data for 14100320 already exists
# Input table_id 14-10-0342-01
# Getting metadata for 14100342
# Metadata and data for 14100342 already exists
# Input table_id 14-10-0354-01
# Getting metadata for 14100354
# Metadata and data for 14100354 already exists
# Input table_id 14-10-0355-01
# Getting metadata for 14100355
# Metadata and data for 14100355 already exists
# Input table_id 14-10-0355-02
# Getting metadata for 14100355
# Metadata and data for 14100355 already exists
# Input table_id 14-10-0373-01
# Getting metadata for 14100373
# Metadata and data for 14100373 already exists
# Input table_id 14-10-0373-02
# Getting metadata for 14100373
# Metadata and data for 14100373 already exists
# Input table_id 14-10-0374-01
# Getting metadata for 14100374
# Metadata and data for 14100374 already exists
# Input table_id 14-10-0376-01
# Getting metadata for 14100376
# Metadata and data for 14100376 already exists
# Input table_id 14-10-0397-01
# Getting metadata for 14100397
# Metadata and data for 14100397 already exists
# Input table_id 14-10-0401-01
# Getting metadata for 14100401
# Metadata and data for 14100401 already exists
# Input table_id 14-10-0421-01
# Getting metadata for 14100421
# Metadata and data for 14100421 already exists
# Input table_id 14-10-0422-01
# Getting metadata for 14100422
# Metadata and data for 14100422 already exists
# Input table_id 14-10-0423-01
# Getting metadata for 14100423
# Metadata and data for 14100423 already exists
# Input table_id 14-10-0424-01
# Getting metadata for 14100424
# Metadata and data for 14100424 already exists
# Input table_id 14-10-0425-01
# Getting metadata for 14100425
# Metadata and data for 14100425 already exists
# Input table_id 14-10-0426-01
# Getting metadata for 14100426
# Metadata and data for 14100426 already exists
# Input table_id 14-10-0427-01
# Getting metadata for 14100427
# Metadata and data for 14100427 already exists
# Input table_id 14-10-0428-01
# Getting metadata for 14100428
# Metadata and data for 14100428 already exists
# Input table_id 14-10-0445-01
# Getting metadata for 14100445
# Metadata and data for 14100445 already exists
# Input table_id 14-10-0458-01
# Getting metadata for 14100458
# Metadata and data for 14100458 already exists
# Input table_id 14-10-0459-01
# Getting metadata for 14100459
# Metadata and data for 14100459 already exists
# Input table_id 14-10-0459-02
# Getting metadata for 14100459
# Metadata and data for 14100459 already exists
# Input table_id 14-10-0460-01
# Getting metadata for 14100460
# Metadata and data for 14100460 already exists
# Input table_id 14-10-0460-02
# Getting metadata for 14100460
# Metadata and data for 14100460 already exists
# Input table_id 14-10-0462-01
# Getting metadata for 14100462
# Metadata and data for 14100462 already exists
# Input table_id 14-10-0462-02
# Getting metadata for 14100462
# Metadata and data for 14100462 already exists
# Input table_id 14-10-0465-01
# Getting metadata for 14100465
# Metadata and data for 14100465 already exists
# Input table_id 14-10-0465-02
# Getting metadata for 14100465
# Metadata and data for 14100465 already exists
# Input table_id 14-10-0465-03
# Getting metadata for 14100465
# Metadata and data for 14100465 already exists
# Input table_id 14-10-0467-01
# Getting metadata for 14100467
# Metadata and data for 14100467 already exists
# Input table_id 14-10-0467-02
# Getting metadata for 14100467
# Metadata and data for 14100467 already exists
# Input table_id 14-10-0467-03
# Getting metadata for 14100467
# Metadata and data for 14100467 already exists
# Input table_id 14-10-0471-01
# Getting metadata for 14100471
# Metadata and data for 14100471 already exists
# Input table_id 14-10-0471-02
# Getting metadata for 14100471
# Metadata and data for 14100471 already exists
# Input table_id 23-10-0081-01
# Getting metadata for 23100081
# Metadata and data for 23100081 already exists
# Input table_id 23-10-0082-01
# Getting metadata for 23100082
# Metadata and data for 23100082 already exists
# Input table_id 23-10-0083-01
# Getting metadata for 23100083
# Metadata and data for 23100083 already exists
# Input table_id 23-10-0084-01
# Getting metadata for 23100084
# Metadata and data for 23100084 already exists
# Input table_id 23-10-0086-01
# Getting metadata for 23100086
# Metadata and data for 23100086 already exists
# Input table_id 23-10-0305-01
# Getting metadata for 23100305
# Metadata and data for 23100305 already exists
# Input table_id 23-10-0306-01
# Getting metadata for 23100306
# Metadata and data for 23100306 already exists
# Input table_id 27-10-0005-01
# Getting metadata for 27100005
# Metadata and data for 27100005 already exists
# Input table_id 27-10-0006-01
# Getting metadata for 27100006
# Metadata and data for 27100006 already exists
# Input table_id 27-10-0007-01
# Getting metadata for 27100007
# Metadata and data for 27100007 already exists
# Input table_id 27-10-0008-01
# Getting metadata for 27100008
# Metadata and data for 27100008 already exists
# Input table_id 27-10-0009-01
# Getting metadata for 27100009
# Metadata and data for 27100009 already exists
# Input table_id 27-10-0010-01
# Getting metadata for 27100010
# Metadata and data for 27100010 already exists
# Input table_id 27-10-0011-01
# Getting metadata for 27100011
# Metadata and data for 27100011 already exists
# Input table_id 27-10-0012-01
# Getting metadata for 27100012
# Metadata and data for 27100012 already exists
# Input table_id 27-10-0013-01
# Getting metadata for 27100013
# Metadata and data for 27100013 already exists
# Input table_id 27-10-0014-01
# Getting metadata for 27100014
# Metadata and data for 27100014 already exists
# Input table_id 27-10-0026-01
# Getting metadata for 27100026
# Metadata and data for 27100026 already exists
# Input table_id 27-10-0027-01
# Getting metadata for 27100027
# Metadata and data for 27100027 already exists
# Input table_id 27-10-0028-01
# Getting metadata for 27100028
# Metadata and data for 27100028 already exists
# Input table_id 27-10-0029-01
# Getting metadata for 27100029
# Metadata and data for 27100029 already exists
# Input table_id 10-10-0123-01
# Getting metadata for 10100123
# Metadata and data for 10100123 already exists
# Input table_id 10-10-0132-01
# Getting metadata for 10100132
# Metadata and data for 10100132 already exists
# Input table_id 10-10-0138-01
# Getting metadata for 10100138
# Metadata and data for 10100138 already exists
# Input table_id 10-10-0143-01
# Getting metadata for 10100143
# Metadata and data for 10100143 already exists
# Input table_id 10-10-0145-01
# Getting metadata for 10100145
# Metadata and data for 10100145 already exists
# Input table_id 20-10-0080-01
# Getting metadata for 20100080
# Metadata and data for 20100080 already exists
# Input table_id 36-10-0368-01
# Getting metadata for 36100368
# Metadata and data for 36100368 already exists
# Input table_id 36-10-0581-01
# Getting metadata for 36100581
# Metadata and data for 36100581 already exists
# Input table_id 36-10-0602-01
# Getting metadata for 36100602
# Metadata and data for 36100602 already exists
# Input table_id 36-10-0605-01
# Getting metadata for 36100605
# Metadata and data for 36100605 already exists
# Input table_id 36-10-0606-01
# Getting metadata for 36100606
# Metadata and data for 36100606 already exists
# Input table_id 36-10-0621-01
# Getting metadata for 36100621
# Metadata and data for 36100621 already exists
# Input table_id 36-10-0621-02
# Getting metadata for 36100621
# Metadata and data for 36100621 already exists
# Input table_id 36-10-0622-01
# Getting metadata for 36100622
# Metadata and data for 36100622 already exists
# Input table_id 36-10-0622-02
# Getting metadata for 36100622
# Metadata and data for 36100622 already exists
# Input table_id 36-10-0643-01
# Getting metadata for 36100643
# Metadata and data for 36100643 already exists
# Input table_id 36-10-0644-01
# Getting metadata for 36100644
# Metadata and data for 36100644 already exists
# Input table_id 36-10-0673-01
# Getting metadata for 36100673
# Metadata and data for 36100673 already exists
# Input table_id 46-10-0090-01
# Getting metadata for 46100090
# Metadata and data for 46100090 already exists
# Input table_id 46-10-0091-01
# Getting metadata for 46100091
# Metadata and data for 46100091 already exists
# Input table_id 22-10-0004-01
# Getting metadata for 22100004
# Metadata and data for 22100004 already exists
# Input table_id 22-10-0005-01
# Getting metadata for 22100005
# Metadata and data for 22100005 already exists
# Input table_id 22-10-0006-01
# Getting metadata for 22100006
# Metadata and data for 22100006 already exists
# Input table_id 32-10-0098-01
# Getting metadata for 32100098
# Metadata and data for 32100098 already exists
# Input table_id 32-10-0099-01
# Getting metadata for 32100099
# Metadata and data for 32100099 already exists
# Input table_id 32-10-0100-01
# Getting metadata for 32100100
# Metadata and data for 32100100 already exists
# Input table_id 10-10-0127-01
# Getting metadata for 10100127
# Metadata and data for 10100127 already exists
# Input table_id 10-10-0144-01
# Getting metadata for 10100144
# Metadata and data for 10100144 already exists
# Input table_id 12-10-0011-01
# Getting metadata for 12100011
# Metadata and data for 12100011 already exists
# Input table_id 12-10-0099-01
# Getting metadata for 12100099
# Metadata and data for 12100099 already exists
# Input table_id 12-10-0127-01
# Getting metadata for 12100127
# Metadata and data for 12100127 already exists
# Input table_id 12-10-0144-01
# Getting metadata for 12100144
# Metadata and data for 12100144 already exists
# Input table_id 12-10-0163-01
# Getting metadata for 12100163
# Metadata and data for 12100163 already exists
# Input table_id 12-10-0163-02
# Getting metadata for 12100163
# Metadata and data for 12100163 already exists
# Input table_id 12-10-0164-01
# Getting metadata for 12100164
# Metadata and data for 12100164 already exists
# Input table_id 12-10-0166-01
# Getting metadata for 12100166
# Metadata and data for 12100166 already exists
# Input table_id 12-10-0167-01
# Getting metadata for 12100167
# Metadata and data for 12100167 already exists
# Input table_id 12-10-0168-01
# Getting metadata for 12100168
# Metadata and data for 12100168 already exists
# Input table_id 12-10-0169-01
# Getting metadata for 12100169
# Metadata and data for 12100169 already exists
# Input table_id 12-10-0170-01
# Getting metadata for 12100170
# Metadata and data for 12100170 already exists
# Input table_id 12-10-0174-01
# Getting metadata for 12100174
# Metadata and data for 12100174 already exists
# Input table_id 12-10-0175-01
# Getting metadata for 12100175
# Metadata and data for 12100175 already exists
# Input table_id 12-10-0176-01
# Getting metadata for 12100176
# Metadata and data for 12100176 already exists
# Input table_id 12-10-0177-01
# Getting metadata for 12100177
# Metadata and data for 12100177 already exists
# Input table_id 12-10-0178-01
# Getting metadata for 12100178
# Metadata and data for 12100178 already exists
# Input table_id 12-10-0179-01
# Getting metadata for 12100179
# Metadata and data for 12100179 already exists
# Input table_id 11-10-0102-01
# Getting metadata for 11100102
# Metadata and data for 11100102 already exists
# Input table_id 11-10-0103-01
# Getting metadata for 11100103
# Metadata and data for 11100103 already exists
# Input table_id 33-10-0163-01
# Getting metadata for 33100163
# Metadata and data for 33100163 already exists
# Input table_id 16-10-0029-01
# Getting metadata for 16100029
# Metadata and data for 16100029 already exists
# Input table_id 16-10-0030-01
# Getting metadata for 16100030
# Metadata and data for 16100030 already exists
# Input table_id 16-10-0031-01
# Getting metadata for 16100031
# Metadata and data for 16100031 already exists
# Input table_id 16-10-0032-01
# Getting metadata for 16100032
# Metadata and data for 16100032 already exists
# Input table_id 62-013-X
# productId: 62013 not length 8
# Input table_id 36-10-0206-01
# Getting metadata for 36100206
# Metadata and data for 36100206 already exists
# Input table_id 36-10-0207-01
# Getting metadata for 36100207
# Metadata and data for 36100207 already exists
# Input table_id 14-10-0452-01
# Getting metadata for 14100452
# Metadata and data for 14100452 already exists
# Input table_id 16-10-0017-01
# Getting metadata for 16100017
# Metadata and data for 16100017 already exists
# Input table_id 16-10-0017-02
# Getting metadata for 16100017
# Metadata and data for 16100017 already exists
# Input table_id 16-10-0017-03
# Getting metadata for 16100017
# Metadata and data for 16100017 already exists
# Input table_id 16-10-0017-04
# Getting metadata for 16100017
# Metadata and data for 16100017 already exists
# Input table_id 16-10-0017-05
# Getting metadata for 16100017
# Metadata and data for 16100017 already exists
# Input table_id 16-10-0017-06
# Getting metadata for 16100017
# Metadata and data for 16100017 already exists
# Input table_id 16-10-0017-07
# Getting metadata for 16100017
# Metadata and data for 16100017 already exists
# Input table_id 16-10-0046-01
# Getting metadata for 16100046
# Metadata and data for 16100046 already exists
# Input table_id 17-10-0160-01
# Getting metadata for 17100160
# Metadata and data for 17100160 already exists
# Input table_id 17-10-0161-01
# Getting metadata for 17100161
# Metadata and data for 17100161 already exists
# Input table_id 10-10-0113-01
# Getting metadata for 10100113
# Metadata and data for 10100113 already exists
# Input table_id 18-10-0245-01
# Getting metadata for 18100245
# Metadata and data for 18100245 already exists
# Input table_id 18-10-0245-02
# Getting metadata for 18100245
# Metadata and data for 18100245 already exists
# Input table_id 36-10-0653-01
# Getting metadata for 36100653
# Metadata and data for 36100653 already exists
# Input table_id 36-10-0654-01
# Getting metadata for 36100654
# Metadata and data for 36100654 already exists
# Input table_id 23-10-0312-01
# Getting metadata for 23100312
# Metadata and data for 23100312 already exists
# Input table_id 25-10-0015-01
# Getting metadata for 25100015
# Metadata and data for 25100015 already exists
# Input table_id 25-10-0016-01
# Getting metadata for 25100016
# Metadata and data for 25100016 already exists
# Input table_id 25-10-0036-01
# Getting metadata for 25100036
# Metadata and data for 25100036 already exists
# Input table_id 25-10-0045-01
# Getting metadata for 25100045
# Metadata and data for 25100045 already exists
# Input table_id 25-10-0046-01
# Getting metadata for 25100046
# Metadata and data for 25100046 already exists
# Input table_id 25-10-0054-01
# Getting metadata for 25100054
# Metadata and data for 25100054 already exists
# Input table_id 25-10-0055-01
# Getting metadata for 25100055
# Metadata and data for 25100055 already exists
# Input table_id 25-10-0063-01
# Getting metadata for 25100063
# Metadata and data for 25100063 already exists
# Input table_id 25-10-0079-01
# Getting metadata for 25100079
# Metadata and data for 25100079 already exists
# Input table_id 25-10-0081-01
# Getting metadata for 25100081
# Metadata and data for 25100081 already exists
# Input table_id 25-10-0081-02
# Getting metadata for 25100081
# Metadata and data for 25100081 already exists
# Input table_id 25-10-0082-01
# Getting metadata for 25100082
# Metadata and data for 25100082 already exists
# Input table_id 10-10-0002-01
# Getting metadata for 10100002
# Metadata and data for 10100002 already exists
# Input table_id 10-10-0133-01
# Getting metadata for 10100133
# Metadata and data for 10100133 already exists
# Input table_id 10-10-0148-01
# Getting metadata for 10100148
# Metadata and data for 10100148 already exists
# Input table_id 18-10-0259-01
# Getting metadata for 18100259
# Metadata and data for 18100259 already exists
# Input table_id 20-10-0081-01
# Getting metadata for 20100081
# Metadata and data for 20100081 already exists
# Input table_id 20-10-0082-01
# Getting metadata for 20100082
# Metadata and data for 20100082 already exists
# Input table_id 36-10-0452-01
# Getting metadata for 36100452
# Metadata and data for 36100452 already exists
# Input table_id 36-10-0453-01
# Getting metadata for 36100453
# Metadata and data for 36100453 already exists
# Input table_id 18-10-0212-01
# Getting metadata for 18100212
# Metadata and data for 18100212 already exists
# Input table_id 18-10-0212-02
# Getting metadata for 18100212
# Metadata and data for 18100212 already exists
# Input table_id 24-10-0045-01
# Getting metadata for 24100045
# Metadata and data for 24100045 already exists
# Input table_id 24-10-0064-01
# Getting metadata for 24100064
# Metadata and data for 24100064 already exists
# Input table_id 24-10-0064-02
# Getting metadata for 24100064
# Metadata and data for 24100064 already exists
# Input table_id 24-10-0064-03
# Getting metadata for 24100064
# Metadata and data for 24100064 already exists
# Input table_id 24-10-0064-04
# Getting metadata for 24100064
# Metadata and data for 24100064 already exists
# Input table_id 24-10-0065-01
# Getting metadata for 24100065
# Metadata and data for 24100065 already exists
# Input table_id 24-10-0065-02
# Getting metadata for 24100065
# Metadata and data for 24100065 already exists
# Input table_id 24-10-0065-03
# Getting metadata for 24100065
# Metadata and data for 24100065 already exists
# Input table_id 24-10-0066-01
# Getting metadata for 24100066
# Metadata and data for 24100066 already exists
# Input table_id 10-10-0122-01
# Getting metadata for 10100122
# Metadata and data for 10100122 already exists
# Input table_id 10-10-0134-01
# Getting metadata for 10100134
# Metadata and data for 10100134 already exists
# Input table_id 10-10-0134-02
# Getting metadata for 10100134
# Metadata and data for 10100134 already exists
# Input table_id 12-10-0161-01
# Getting metadata for 12100161
# Metadata and data for 12100161 already exists
# Input table_id 12-10-0162-01
# Getting metadata for 12100162
# Metadata and data for 12100162 already exists
# Input table_id 18-10-0275-01
# Getting metadata for 18100275
# Metadata and data for 18100275 already exists
# Input table_id 18-10-0275-02
# Getting metadata for 18100275
# Metadata and data for 18100275 already exists
# Input table_id 18-10-0281-01
# Getting metadata for 18100281
# Metadata and data for 18100281 already exists
# Input table_id 18-10-0281-02
# Getting metadata for 18100281
# Metadata and data for 18100281 already exists
# Input table_id 18-10-0282-01
# Getting metadata for 18100282
# Metadata and data for 18100282 already exists
# Input table_id 18-10-0282-02
# Getting metadata for 18100282
# Metadata and data for 18100282 already exists
# Input table_id 18-10-0283-01
# Getting metadata for 18100283
# Metadata and data for 18100283 already exists
# Input table_id 18-10-0284-01
# Getting metadata for 18100284
# Metadata and data for 18100284 already exists
# Input table_id 34-10-0163-01
# Getting metadata for 34100163
# Metadata and data for 34100163 already exists
# Input table_id 36-10-0103-01
# Getting metadata for 36100103
# Metadata and data for 36100103 already exists
# Input table_id 36-10-0104-01
# Getting metadata for 36100104
# Metadata and data for 36100104 already exists
# Input table_id 36-10-0105-01
# Getting metadata for 36100105
# Metadata and data for 36100105 already exists
# Input table_id 36-10-0106-01
# Getting metadata for 36100106
# Metadata and data for 36100106 already exists
# Input table_id 36-10-0107-01
# Getting metadata for 36100107
# Metadata and data for 36100107 already exists
# Input table_id 36-10-0108-01
# Getting metadata for 36100108
# Metadata and data for 36100108 already exists
# Input table_id 36-10-0109-01
# Getting metadata for 36100109
# Metadata and data for 36100109 already exists
# Input table_id 36-10-0111-01
# Getting metadata for 36100111
# Metadata and data for 36100111 already exists
# Input table_id 36-10-0112-01
# Getting metadata for 36100112
# Metadata and data for 36100112 already exists
# Input table_id 36-10-0114-01
# Getting metadata for 36100114
# Metadata and data for 36100114 already exists
# Input table_id 36-10-0115-01
# Getting metadata for 36100115
# Metadata and data for 36100115 already exists
# Input table_id 36-10-0116-01
# Getting metadata for 36100116
# Metadata and data for 36100116 already exists
# Input table_id 36-10-0117-01
# Getting metadata for 36100117
# Metadata and data for 36100117 already exists
# Input table_id 36-10-0118-01
# Getting metadata for 36100118
# Metadata and data for 36100118 already exists
# Input table_id 36-10-0121-01
# Getting metadata for 36100121
# Metadata and data for 36100121 already exists
# Input table_id 36-10-0122-01
# Getting metadata for 36100122
# Metadata and data for 36100122 already exists
# Input table_id 36-10-0123-01
# Getting metadata for 36100123
# Metadata and data for 36100123 already exists
# Input table_id 36-10-0124-01
# Getting metadata for 36100124
# Metadata and data for 36100124 already exists
# Input table_id 36-10-0125-01
# Getting metadata for 36100125
# Metadata and data for 36100125 already exists
# Input table_id 36-10-0126-01
# Getting metadata for 36100126
# Metadata and data for 36100126 already exists
# Input table_id 36-10-0127-01
# Getting metadata for 36100127
# Metadata and data for 36100127 already exists
# Input table_id 36-10-0128-01
# Getting metadata for 36100128
# Metadata and data for 36100128 already exists
# Input table_id 36-10-0129-01
# Getting metadata for 36100129
# Metadata and data for 36100129 already exists
# Input table_id 36-10-0130-01
# Getting metadata for 36100130
# Metadata and data for 36100130 already exists
# Input table_id 36-10-0131-01
# Getting metadata for 36100131
# Metadata and data for 36100131 already exists
# Input table_id 36-10-0132-01
# Getting metadata for 36100132
# Metadata and data for 36100132 already exists
# Input table_id 36-10-0135-01
# Getting metadata for 36100135
# Metadata and data for 36100135 already exists
# Input table_id 36-10-0205-01
# Getting metadata for 36100205
# Metadata and data for 36100205 already exists
# Input table_id 36-10-0369-01
# Getting metadata for 36100369
# Metadata and data for 36100369 already exists
# Input table_id 36-10-0434-01
# Getting metadata for 36100434
# Metadata and data for 36100434 already exists
# Input table_id 36-10-0434-02
# Getting metadata for 36100434
# Metadata and data for 36100434 already exists
# Input table_id 36-10-0434-03
# Getting metadata for 36100434
# Metadata and data for 36100434 already exists
# Input table_id 36-10-0434-04
# Getting metadata for 36100434
# Metadata and data for 36100434 already exists
# Input table_id 36-10-0434-05
# Getting metadata for 36100434
# Metadata and data for 36100434 already exists
# Input table_id 36-10-0434-06
# Getting metadata for 36100434
# Metadata and data for 36100434 already exists
# Input table_id 36-10-0449-01
# Getting metadata for 36100449
# Metadata and data for 36100449 already exists
# Input table_id 36-10-0477-01
# Getting metadata for 36100477
# Metadata and data for 36100477 already exists
# Input table_id 36-10-0484-01
# Getting metadata for 36100484
# Metadata and data for 36100484 already exists
# Input table_id 36-10-0688-01
# Getting metadata for 36100688
# Metadata and data for 36100688 already exists
# Input table_id 36-10-0699-01
# Getting metadata for 36100699
# Metadata and data for 36100699 already exists
# Input table_id 36-10-0706-01
# Getting metadata for 36100706
# Metadata and data for 36100706 already exists
# Input table_id 14-10-0201-01
# Getting metadata for 14100201
# Metadata and data for 14100201 already exists
# Input table_id 14-10-0201-02
# Getting metadata for 14100201
# Metadata and data for 14100201 already exists
# Input table_id 14-10-0203-01
# Getting metadata for 14100203
# Metadata and data for 14100203 already exists
# Input table_id 14-10-0205-01
# Getting metadata for 14100205
# Metadata and data for 14100205 already exists
# Input table_id 14-10-0209-01
# Getting metadata for 14100209
# Metadata and data for 14100209 already exists
# Input table_id 14-10-0211-01
# Getting metadata for 14100211
# Metadata and data for 14100211 already exists
# Input table_id 14-10-0213-01
# Getting metadata for 14100213
# Metadata and data for 14100213 already exists
# Input table_id 14-10-0220-01
# Getting metadata for 14100220
# Metadata and data for 14100220 already exists
# Input table_id 14-10-0220-02
# Getting metadata for 14100220
# Metadata and data for 14100220 already exists
# Input table_id 14-10-0221-01
# Getting metadata for 14100221
# Metadata and data for 14100221 already exists
# Input table_id 14-10-0222-01
# Getting metadata for 14100222
# Metadata and data for 14100222 already exists
# Input table_id 14-10-0223-01
# Getting metadata for 14100223
# Metadata and data for 14100223 already exists
# Input table_id 14-10-0255-01
# Getting metadata for 14100255
# Metadata and data for 14100255 already exists
# Input table_id 14-10-0371-01
# Getting metadata for 14100371
# Metadata and data for 14100371 already exists
# Input table_id 14-10-0372-01
# Getting metadata for 14100372
# Metadata and data for 14100372 already exists
# Input table_id 14-10-0406-01
# Getting metadata for 14100406
# Metadata and data for 14100406 already exists
# Input table_id 14-10-0432-01
# Getting metadata for 14100432
# Metadata and data for 14100432 already exists
# Input table_id 16-10-0044-01
# Getting metadata for 16100044
# Metadata and data for 16100044 already exists
# Input table_id 18-10-0178-01
# Getting metadata for 18100178
# Metadata and data for 18100178 already exists
# Input table_id 18-10-0178-02
# Getting metadata for 18100178
# Metadata and data for 18100178 already exists
# Input table_id 32-10-0117-01
# Getting metadata for 32100117
# Metadata and data for 32100117 already exists
# Input table_id 32-10-0118-01
# Getting metadata for 32100118
# Metadata and data for 32100118 already exists
# Input table_id 32-10-0119-01
# Getting metadata for 32100119
# Metadata and data for 32100119 already exists
# Input table_id 32-10-0120-01
# Getting metadata for 32100120
# Metadata and data for 32100120 already exists
# Input table_id 32-10-0121-01
# Getting metadata for 32100121
# Metadata and data for 32100121 already exists
# Input table_id 32-10-0122-01
# Getting metadata for 32100122
# Metadata and data for 32100122 already exists
# Input table_id 32-10-0123-01
# Getting metadata for 32100123
# Metadata and data for 32100123 already exists
# Input table_id 32-10-0133-01
# Getting metadata for 32100133
# Metadata and data for 32100133 already exists
# Input table_id 32-10-0134-01
# Getting metadata for 32100134
# Metadata and data for 32100134 already exists
# Input table_id 32-10-0135-01
# Getting metadata for 32100135
# Metadata and data for 32100135 already exists
# Input table_id 12-10-0157-01
# Getting metadata for 12100157
# Metadata and data for 12100157 already exists
# Input table_id 36-10-0002-01
# Getting metadata for 36100002
# Metadata and data for 36100002 already exists
# Input table_id 36-10-0003-01
# Getting metadata for 36100003
# Metadata and data for 36100003 already exists
# Input table_id 36-10-0014-01
# Getting metadata for 36100014
# Metadata and data for 36100014 already exists
# Input table_id 36-10-0016-01
# Getting metadata for 36100016
# Metadata and data for 36100016 already exists
# Input table_id 36-10-0018-01
# Getting metadata for 36100018
# Metadata and data for 36100018 already exists
# Input table_id 36-10-0019-01
# Getting metadata for 36100019
# Metadata and data for 36100019 already exists
# Input table_id 36-10-0020-01
# Getting metadata for 36100020
# Metadata and data for 36100020 already exists
# Input table_id 36-10-0021-01
# Getting metadata for 36100021
# Metadata and data for 36100021 already exists
# Input table_id 36-10-0023-01
# Getting metadata for 36100023
# Metadata and data for 36100023 already exists
# Input table_id 36-10-0025-01
# Getting metadata for 36100025
# Metadata and data for 36100025 already exists
# Input table_id 36-10-0026-01
# Getting metadata for 36100026
# Metadata and data for 36100026 already exists
# Input table_id 36-10-0027-01
# Getting metadata for 36100027
# Metadata and data for 36100027 already exists
# Input table_id 36-10-0442-01
# Getting metadata for 36100442
# Metadata and data for 36100442 already exists
# Input table_id 36-10-0471-01
# Getting metadata for 36100471
# Metadata and data for 36100471 already exists
# Input table_id 36-10-0472-01
# Getting metadata for 36100472
# Metadata and data for 36100472 already exists
# Input table_id 36-10-0473-01
# Getting metadata for 36100473
# Metadata and data for 36100473 already exists
# Input table_id 36-10-0656-01
# Getting metadata for 36100656
# Metadata and data for 36100656 already exists
# Input table_id 23-10-0079-01
# Getting metadata for 23100079
# Metadata and data for 23100079 already exists
# Input table_id 23-10-0258-01
# Getting metadata for 23100258
# Metadata and data for 23100258 already exists
# Input table_id 23-10-0259-01
# Getting metadata for 23100259
# Metadata and data for 23100259 already exists
# Input table_id 23-10-0260-01
# Getting metadata for 23100260
# Metadata and data for 23100260 already exists
# Input table_id 23-10-0261-01
# Getting metadata for 23100261
# Metadata and data for 23100261 already exists
# Input table_id 23-10-0262-01
# Getting metadata for 23100262
# Metadata and data for 23100262 already exists
# Input table_id 23-10-0296-01
# Getting metadata for 23100296
# Metadata and data for 23100296 already exists
# Input table_id 23-10-0297-01
# Getting metadata for 23100297
# Metadata and data for 23100297 already exists
# Input table_id 23-10-0298-01
# Getting metadata for 23100298
# Metadata and data for 23100298 already exists
# Input table_id 23-10-0299-01
# Getting metadata for 23100299
# Metadata and data for 23100299 already exists
# Input table_id 23-10-0300-01
# Getting metadata for 23100300
# Metadata and data for 23100300 already exists
# Input table_id 23-10-0301-01
# Getting metadata for 23100301
# Metadata and data for 23100301 already exists
# Input table_id 23-10-0302-01
# Getting metadata for 23100302
# Metadata and data for 23100302 already exists
# Input table_id 23-10-0303-01
# Getting metadata for 23100303
# Metadata and data for 23100303 already exists
# Input table_id 23-10-0304-01
# Getting metadata for 23100304
# Metadata and data for 23100304 already exists
# Input table_id 32-10-0045-01
# Getting metadata for 32100045
# Metadata and data for 32100045 already exists
# Input table_id 32-10-0046-01
# Getting metadata for 32100046
# Metadata and data for 32100046 already exists
# Input table_id 32-10-0047-01
# Getting metadata for 32100047
# Metadata and data for 32100047 already exists
# Input table_id 32-10-0049-01
# Getting metadata for 32100049
# Metadata and data for 32100049 already exists
# Input table_id 32-10-0050-01
# Getting metadata for 32100050
# Metadata and data for 32100050 already exists
# Input table_id 32-10-0051-01
# Getting metadata for 32100051
# Metadata and data for 32100051 already exists
# Input table_id 32-10-0052-01
# Getting metadata for 32100052
# Metadata and data for 32100052 already exists
# Input table_id 32-10-0055-01
# Getting metadata for 32100055
# Metadata and data for 32100055 already exists
# Input table_id 32-10-0105-01
# Getting metadata for 32100105
# Metadata and data for 32100105 already exists
# Input table_id 32-10-0106-01
# Getting metadata for 32100106
# Metadata and data for 32100106 already exists
# Input table_id 32-10-0124-01
# Getting metadata for 32100124
# Metadata and data for 32100124 already exists
# Input table_id 13-10-0955-01
# Getting metadata for 13100955
# Metadata and data for 13100955 already exists
# Input table_id 13-10-0956-01
# Getting metadata for 13100956
# Metadata and data for 13100956 already exists
# Input table_id 13-10-0957-01
# Getting metadata for 13100957
# Metadata and data for 13100957 already exists
# Input table_id 21-10-0019-01
# Getting metadata for 21100019
# Metadata and data for 21100019 already exists
# Input table_id 45-20-00012025001
# Getting metadata for 45200001
# The cube product ID 45200001 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 33-10-0979-01
# Getting metadata for 33100979
# Metadata and data for 33100979 already exists
# Input table_id 33-10-0980-01
# Getting metadata for 33100980
# Metadata and data for 33100980 already exists
# Input table_id 33-10-0981-01
# Getting metadata for 33100981
# Metadata and data for 33100981 already exists
# Input table_id 33-10-0982-01
# Getting metadata for 33100982
# Metadata and data for 33100982 already exists
# Input table_id 33-10-0983-01
# Getting metadata for 33100983
# Metadata and data for 33100983 already exists
# Input table_id 33-10-0984-01
# Getting metadata for 33100984
# Metadata and data for 33100984 already exists
# Input table_id 33-10-0985-01
# Getting metadata for 33100985
# Metadata and data for 33100985 already exists
# Input table_id 33-10-0986-01
# Getting metadata for 33100986
# Metadata and data for 33100986 already exists
# Input table_id 33-10-0987-01
# Getting metadata for 33100987
# Metadata and data for 33100987 already exists
# Input table_id 33-10-0988-01
# Getting metadata for 33100988
# Metadata and data for 33100988 already exists
# Input table_id 33-10-0989-01
# Getting metadata for 33100989
# Metadata and data for 33100989 already exists
# Input table_id 33-10-0990-01
# Getting metadata for 33100990
# Metadata and data for 33100990 already exists
# Input table_id 33-10-0991-01
# Getting metadata for 33100991
# Metadata and data for 33100991 already exists
# Input table_id 33-10-0992-01
# Getting metadata for 33100992
# Metadata and data for 33100992 already exists
# Input table_id 33-10-0993-01
# Getting metadata for 33100993
# Metadata and data for 33100993 already exists
# Input table_id 33-10-0994-01
# Getting metadata for 33100994
# Metadata and data for 33100994 already exists
# Input table_id 33-10-0995-01
# Getting metadata for 33100995
# Metadata and data for 33100995 already exists
# Input table_id 33-10-0996-01
# Getting metadata for 33100996
# Metadata and data for 33100996 already exists
# Input table_id 33-10-0997-01
# Getting metadata for 33100997
# Metadata and data for 33100997 already exists
# Input table_id 33-10-0998-01
# Getting metadata for 33100998
# Metadata and data for 33100998 already exists
# Input table_id 33-10-0999-01
# Getting metadata for 33100999
# Metadata and data for 33100999 already exists
# Input table_id 33-10-1000-01
# Getting metadata for 33101000
# Metadata and data for 33101000 already exists
# Input table_id 33-10-1001-01
# Getting metadata for 33101001
# Metadata and data for 33101001 already exists
# Input table_id 33-10-1002-01
# Getting metadata for 33101002
# Metadata and data for 33101002 already exists
# Input table_id 33-10-1003-01
# Getting metadata for 33101003
# Metadata and data for 33101003 already exists
# Input table_id 33-10-1004-01
# Getting metadata for 33101004
# Metadata and data for 33101004 already exists
# Input table_id 33-10-1005-01
# Getting metadata for 33101005
# Metadata and data for 33101005 already exists
# Input table_id 33-10-1006-01
# Getting metadata for 33101006
# Metadata and data for 33101006 already exists
# Input table_id 33-10-1007-01
# Getting metadata for 33101007
# Metadata and data for 33101007 already exists
# Input table_id 33-10-1008-01
# Getting metadata for 33101008
# Metadata and data for 33101008 already exists
# Input table_id 33-10-1009-01
# Getting metadata for 33101009
# Metadata and data for 33101009 already exists
# Input table_id 33-10-1010-01
# Getting metadata for 33101010
# Metadata and data for 33101010 already exists
# Input table_id 33-10-1011-01
# Getting metadata for 33101011
# Metadata and data for 33101011 already exists
# Input table_id 33-10-1012-01
# Getting metadata for 33101012
# Metadata and data for 33101012 already exists
# Input table_id 33-10-1013-01
# Getting metadata for 33101013
# Metadata and data for 33101013 already exists
# Input table_id 36-10-0691-01
# Getting metadata for 36100691
# Metadata and data for 36100691 already exists
# Input table_id 36-10-0692-01
# Getting metadata for 36100692
# Metadata and data for 36100692 already exists
# Input table_id 36-10-0693-01
# Getting metadata for 36100693
# Metadata and data for 36100693 already exists
# Input table_id 36-10-0694-01
# Getting metadata for 36100694
# Metadata and data for 36100694 already exists
# Input table_id 33-10-0270-01
# Getting metadata for 33100270
# Metadata and data for 33100270 already exists
# Input table_id 32-10-0351-01
# Getting metadata for 32100351
# Metadata and data for 32100351 already exists
# Input table_id 32-10-0352-01
# Getting metadata for 32100352
# Metadata and data for 32100352 already exists
# Input table_id 20-10-0005-01
# Getting metadata for 20100005
# Metadata and data for 20100005 already exists
# Input table_id 20-10-0020-01
# Getting metadata for 20100020
# Metadata and data for 20100020 already exists
# Input table_id 33-10-0722-01
# Getting metadata for 33100722
# Metadata and data for 33100722 already exists
# Input table_id 34-10-0286-01
# Getting metadata for 34100286
# Metadata and data for 34100286 already exists
# Input table_id 33-10-0224-01
# Getting metadata for 33100224
# Metadata and data for 33100224 already exists
# Input table_id 33-10-0225-01
# Getting metadata for 33100225
# Metadata and data for 33100225 already exists
# Input table_id 33-10-0226-01
# Getting metadata for 33100226
# Metadata and data for 33100226 already exists
# Input table_id 33-10-0227-01
# Getting metadata for 33100227
# Metadata and data for 33100227 already exists
# Input table_id 16-10-0014-01
# Getting metadata for 16100014
# Metadata and data for 16100014 already exists
# Input table_id 16-10-0015-01
# Getting metadata for 16100015
# ...
# Input table_id 97-570-X1991054
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991055
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991056
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991057
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991058
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991059
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991060
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991061
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991062
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991063
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991064
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991065
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991066
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991067
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991068
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991069
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991070
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991071
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991072
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991073
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991074
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991075
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991076
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991077
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991078
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991079
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991080
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991081
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991082
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991083
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991084
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991085
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991086
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991087
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991088
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991089
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991090
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991091
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991092
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991093
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991094
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991095
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991096
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991097
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991098
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991099
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991100
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991101
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991102
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991103
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991104
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991105
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991106
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991107
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991108
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991109
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991120
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991121
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991122
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991123
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991124
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991125
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991126
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991127
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991128
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991129
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991130
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991131
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991132
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991133
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991134
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991135
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991136
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991137
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991138
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991139
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991143
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991144
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991145
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991146
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991147
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991148
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991149
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991150
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991151
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991152
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991153
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991154
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991155
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991156
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991157
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991158
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991159
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991160
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991161
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991162
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991163
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991164
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991165
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991166
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991167
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991168
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991169
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991170
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991171
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991172
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991173
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991174
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991175
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991176
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991177
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991182
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991183
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 97-570-X1991184
# Getting metadata for 97570199
# The cube product ID 97570199 does not exist. Error code = CUBE_NOT_AVAILABLE
# Input table_id 95F0168X
# productId: 950168 not length 8
# Input table_id 75-001-X19890022277
# Getting metadata for 75001198
# The cube product ID 75001198 does not exist. Error code = CUBE_NOT_AVAILABLE

# %%
def process_table(table_id):
    already_processed = len(cur.execute("SELECT * FROM processed WHERE table_id = ?", (table_id,)).fetchall())
    if already_processed:
        print(f"Already processed {table_id}")
        return
    
    print(f"Processing {table_id}")
    try:
        df = sc.table_to_df(table_id)[['DGUID']].drop_duplicates()
        df.columns = [x.lower() for x in df.columns]
        df['table_id'] = table_id
        df.to_sql(name='dguid_table_id', con=con, if_exists='append', index=False)
        values = (table_id, 'success')
        cur.execute("INSERT INTO processed VALUES(?, ?)", values)
        con.commit()
    except Exception as e:
        values = (table_id, str(e))
        print(f"Failed to process {table_id}")
        cur.execute("INSERT INTO processed VALUES(?, ?)", values)
        con.commit()
